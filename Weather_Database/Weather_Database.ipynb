# %%
#import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from citipy import citipy
import requests
from datetime import datetime 
from config import weather_api_key

# %%
#create a new set of random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
coordinates = zip(lats,lngs)
coordinates

# %%
#add the coordinates to a list
coordinates = list(coordinates)

# %%
#get the nearest city using the citipy module
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 754

# %%
#perform an API call with the OpenWeatherMap
city_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#retrieve information from the API call.

#create an empty list to hold the weather data
city_data = []
#print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
#create counters.
record_count = 1
set_count = 1

#loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city.
    url = city_url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_wdesc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_wdesc})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | khovu-aksy
# Processing Record 2 of Set 1 | vaini
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | rexburg
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | qaanaaq
# Processing Record 8 of Set 1 | pevek
# Processing Record 9 of Set 1 | dukat
# Processing Record 10 of Set 1 | egvekinot
# Processing Record 11 of Set 1 | provideniya
# Processing Record 12 of Set 1 | hermanus
# Processing Record 13 of Set 1 | alofi
# Processing Record 14 of Set 1 | avarua
# Processing Record 15 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 1 | bundi
# Processing Record 17 of Set 1 | utiroa
# City not found. Skipping...
# Processing Record 18 of Set 1 | kodiak
# Processing Record 19 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 20 of Set 1 | nikolskoye
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | lakatoro
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | coihaique
# Processing Record 25 of Set 1 | idlib
# Processing Record 26 of Set 1 | bluff
# Processing Record 27 of Set 1 | saint george
# Processing Record 28 of Set 1 | fosser
# City not found. Skipping...
# Processing Record 29 of Set 1 | zyryanka
# Processing Record 30 of Set 1 | san antonio
# Processing Record 31 of Set 1 | turukhansk
# Processing Record 32 of Set 1 | yuancheng
# Processing Record 33 of Set 1 | tasiilaq
# Processing Record 34 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 1 | sebinkarahisar
# Processing Record 36 of Set 1 | yirol
# City not found. Skipping...
# Processing Record 37 of Set 1 | stabat
# Processing Record 38 of Set 1 | butaritari
# Processing Record 39 of Set 1 | kahului
# Processing Record 40 of Set 1 | bredasdorp
# Processing Record 41 of Set 1 | sibolga
# Processing Record 42 of Set 1 | yaan
# Processing Record 43 of Set 1 | ribeira grande
# Processing Record 44 of Set 1 | shelburne
# Processing Record 45 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 47 of Set 1 | yanji
# Processing Record 48 of Set 1 | victoria
# Processing Record 49 of Set 1 | hambantota
# Processing Record 50 of Set 1 | duz
# City not found. Skipping...
# Processing Record 1 of Set 2 | ilulissat
# Processing Record 2 of Set 2 | port elizabeth
# Processing Record 3 of Set 2 | akyab
# Processing Record 4 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 2 | tahoua
# Processing Record 6 of Set 2 | bandar-e lengeh
# Processing Record 7 of Set 2 | port hardy
# Processing Record 8 of Set 2 | chumphon
# Processing Record 9 of Set 2 | speightstown
# Processing Record 10 of Set 2 | lokosovo
# Processing Record 11 of Set 2 | puerto ayora
# Processing Record 12 of Set 2 | moyale
# Processing Record 13 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 2 | bengkulu
# Processing Record 15 of Set 2 | negombo
# Processing Record 16 of Set 2 | bambous virieux
# Processing Record 17 of Set 2 | baykit
# Processing Record 18 of Set 2 | ushuaia
# Processing Record 19 of Set 2 | hasaki
# Processing Record 20 of Set 2 | caledonia
# Processing Record 21 of Set 2 | port alfred
# Processing Record 22 of Set 2 | pekan
# Processing Record 23 of Set 2 | worland
# Processing Record 24 of Set 2 | yulara
# Processing Record 25 of Set 2 | lebu
# Processing Record 26 of Set 2 | san cristobal
# Processing Record 27 of Set 2 | bossangoa
# Processing Record 28 of Set 2 | georgetown
# Processing Record 29 of Set 2 | maniitsoq
# Processing Record 30 of Set 2 | adjumani
# Processing Record 31 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 2 | flin flon
# Processing Record 33 of Set 2 | vila franca do campo
# Processing Record 34 of Set 2 | punta arenas
# Processing Record 35 of Set 2 | cape town
# Processing Record 36 of Set 2 | hilo
# Processing Record 37 of Set 2 | imeni poliny osipenko
# Processing Record 38 of Set 2 | ostrovnoy
# Processing Record 39 of Set 2 | ayan
# Processing Record 40 of Set 2 | kavieng
# Processing Record 41 of Set 2 | bathsheba
# Processing Record 42 of Set 2 | georgiyevka
# Processing Record 43 of Set 2 | east london
# Processing Record 44 of Set 2 | huarmey
# Processing Record 45 of Set 2 | los llanos de aridane
# Processing Record 46 of Set 2 | matara
# Processing Record 47 of Set 2 | atuona
# Processing Record 48 of Set 2 | tuktoyaktuk
# Processing Record 49 of Set 2 | yellowknife
# Processing Record 50 of Set 2 | mvuma
# Processing Record 1 of Set 3 | chalmette
# Processing Record 2 of Set 3 | nizhniy kuranakh
# Processing Record 3 of Set 3 | karratha
# Processing Record 4 of Set 3 | pathein
# Processing Record 5 of Set 3 | ranong
# Processing Record 6 of Set 3 | shakawe
# Processing Record 7 of Set 3 | gat
# Processing Record 8 of Set 3 | havre-saint-pierre
# Processing Record 9 of Set 3 | carauari
# Processing Record 10 of Set 3 | sioux lookout
# Processing Record 11 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 3 | saint stephen
# Processing Record 13 of Set 3 | hirara
# Processing Record 14 of Set 3 | chokurdakh
# Processing Record 15 of Set 3 | mocambique
# City not found. Skipping...
# Processing Record 16 of Set 3 | dingle
# Processing Record 17 of Set 3 | barrow
# Processing Record 18 of Set 3 | kiruna
# Processing Record 19 of Set 3 | cooma
# Processing Record 20 of Set 3 | airai
# Processing Record 21 of Set 3 | rio grande
# Processing Record 22 of Set 3 | norman wells
# Processing Record 23 of Set 3 | pitimbu
# Processing Record 24 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 3 | dikson
# Processing Record 26 of Set 3 | dese
# Processing Record 27 of Set 3 | stephenville
# Processing Record 28 of Set 3 | labuhan
# Processing Record 29 of Set 3 | castro
# Processing Record 30 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 3 | aykhal
# Processing Record 32 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 3 | mosquera
# Processing Record 34 of Set 3 | borborema
# Processing Record 35 of Set 3 | moussoro
# Processing Record 36 of Set 3 | tazovskiy
# Processing Record 37 of Set 3 | union de san antonio
# Processing Record 38 of Set 3 | mutis
# Processing Record 39 of Set 3 | biak
# Processing Record 40 of Set 3 | padang
# Processing Record 41 of Set 3 | new norfolk
# Processing Record 42 of Set 3 | narsaq
# Processing Record 43 of Set 3 | tiksi
# Processing Record 44 of Set 3 | beringovskiy
# Processing Record 45 of Set 3 | labutta
# City not found. Skipping...
# Processing Record 46 of Set 3 | araouane
# Processing Record 47 of Set 3 | birjand
# Processing Record 48 of Set 3 | greeneville
# Processing Record 49 of Set 3 | atar
# Processing Record 50 of Set 3 | bowen
# Processing Record 1 of Set 4 | korla
# Processing Record 2 of Set 4 | sayan
# Processing Record 3 of Set 4 | chuy
# Processing Record 4 of Set 4 | banda aceh
# Processing Record 5 of Set 4 | aleksandrov gay
# Processing Record 6 of Set 4 | hobart
# Processing Record 7 of Set 4 | mungaoli
# Processing Record 8 of Set 4 | ko samui
# Processing Record 9 of Set 4 | marawi
# Processing Record 10 of Set 4 | ca mau
# Processing Record 11 of Set 4 | te anau
# Processing Record 12 of Set 4 | damaturu
# Processing Record 13 of Set 4 | waitati
# Processing Record 14 of Set 4 | valparaiso
# Processing Record 15 of Set 4 | kamaishi
# Processing Record 16 of Set 4 | mackay
# Processing Record 17 of Set 4 | mahebourg
# Processing Record 18 of Set 4 | mar del plata
# Processing Record 19 of Set 4 | san juan
# Processing Record 20 of Set 4 | gizo
# Processing Record 21 of Set 4 | cankuzo
# Processing Record 22 of Set 4 | torbay
# Processing Record 23 of Set 4 | comodoro rivadavia
# Processing Record 24 of Set 4 | husavik
# Processing Record 25 of Set 4 | thompson
# Processing Record 26 of Set 4 | sao jose da coroa grande
# Processing Record 27 of Set 4 | marinette
# Processing Record 28 of Set 4 | richards bay
# Processing Record 29 of Set 4 | wundanyi
# Processing Record 30 of Set 4 | teguldet
# Processing Record 31 of Set 4 | luderitz
# Processing Record 32 of Set 4 | kruisfontein
# Processing Record 33 of Set 4 | katsuura
# Processing Record 34 of Set 4 | salalah
# Processing Record 35 of Set 4 | pisco
# Processing Record 36 of Set 4 | nishihara
# Processing Record 37 of Set 4 | vila velha
# Processing Record 38 of Set 4 | geraldton
# Processing Record 39 of Set 4 | verkhnyaya toyma
# Processing Record 40 of Set 4 | premnitz
# Processing Record 41 of Set 4 | ponta do sol
# Processing Record 42 of Set 4 | babstovo
# Processing Record 43 of Set 4 | hovd
# Processing Record 44 of Set 4 | sidi ali
# Processing Record 45 of Set 4 | tigre
# Processing Record 46 of Set 4 | petauke
# Processing Record 47 of Set 4 | kenai
# Processing Record 48 of Set 4 | rondonopolis
# Processing Record 49 of Set 4 | huejuquilla el alto
# Processing Record 50 of Set 4 | portland
# Processing Record 1 of Set 5 | luba
# Processing Record 2 of Set 5 | leningradskiy
# Processing Record 3 of Set 5 | cidreira
# Processing Record 4 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 5 | mount isa
# Processing Record 6 of Set 5 | alexandroupoli
# Processing Record 7 of Set 5 | lavrentiya
# Processing Record 8 of Set 5 | igarape-miri
# City not found. Skipping...
# Processing Record 9 of Set 5 | ipoti
# Processing Record 10 of Set 5 | alyangula
# Processing Record 11 of Set 5 | kandrian
# Processing Record 12 of Set 5 | boras
# Processing Record 13 of Set 5 | bambanglipuro
# Processing Record 14 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 5 | mezen
# Processing Record 16 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 5 | sao filipe
# Processing Record 18 of Set 5 | clyde river
# Processing Record 19 of Set 5 | guerrero negro
# Processing Record 20 of Set 5 | cherskiy
# Processing Record 21 of Set 5 | kitcharao
# Processing Record 22 of Set 5 | itarema
# Processing Record 23 of Set 5 | pedra azul
# Processing Record 24 of Set 5 | ituni
# City not found. Skipping...
# Processing Record 25 of Set 5 | belaya gora
# Processing Record 26 of Set 5 | lethem
# Processing Record 27 of Set 5 | kavaratti
# Processing Record 28 of Set 5 | vila
# Processing Record 29 of Set 5 | arraial do cabo
# Processing Record 30 of Set 5 | clarksdale
# Processing Record 31 of Set 5 | marsa matruh
# Processing Record 32 of Set 5 | chifeng
# Processing Record 33 of Set 5 | champerico
# Processing Record 34 of Set 5 | kirakira
# Processing Record 35 of Set 5 | bethel
# Processing Record 36 of Set 5 | esperance
# Processing Record 37 of Set 5 | kapustin yar-1
# City not found. Skipping...
# Processing Record 38 of Set 5 | ilebo
# Processing Record 39 of Set 5 | aklavik
# Processing Record 40 of Set 5 | avera
# Processing Record 41 of Set 5 | port-gentil
# Processing Record 42 of Set 5 | morondava
# Processing Record 43 of Set 5 | gazni
# City not found. Skipping...
# Processing Record 44 of Set 5 | balgazyn
# Processing Record 45 of Set 5 | nanortalik
# Processing Record 46 of Set 5 | acapulco
# Processing Record 47 of Set 5 | ancud
# Processing Record 48 of Set 5 | gidole
# Processing Record 49 of Set 5 | kapaa
# Processing Record 50 of Set 5 | gobabis
# Processing Record 1 of Set 6 | jahanabad
# Processing Record 2 of Set 6 | maceio
# Processing Record 3 of Set 6 | kropotkin
# Processing Record 4 of Set 6 | naryan-mar
# Processing Record 5 of Set 6 | coquimbo
# Processing Record 6 of Set 6 | sredniy ikorets
# Processing Record 7 of Set 6 | waingapu
# Processing Record 8 of Set 6 | longyearbyen
# Processing Record 9 of Set 6 | saskylakh
# Processing Record 10 of Set 6 | singaraja
# Processing Record 11 of Set 6 | kailua
# Processing Record 12 of Set 6 | wakkanai
# Processing Record 13 of Set 6 | codrington
# Processing Record 14 of Set 6 | namatanai
# Processing Record 15 of Set 6 | kupang
# Processing Record 16 of Set 6 | fortuna
# Processing Record 17 of Set 6 | bandarbeyla
# Processing Record 18 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 6 | fairbanks
# Processing Record 20 of Set 6 | arlit
# Processing Record 21 of Set 6 | salaga
# Processing Record 22 of Set 6 | port hawkesbury
# Processing Record 23 of Set 6 | otradinskiy
# City not found. Skipping...
# Processing Record 24 of Set 6 | jiwani
# Processing Record 25 of Set 6 | asau
# Processing Record 26 of Set 6 | ust-kuyga
# Processing Record 27 of Set 6 | fort nelson
# Processing Record 28 of Set 6 | ucluelet
# Processing Record 29 of Set 6 | ulaanbaatar
# Processing Record 30 of Set 6 | meulaboh
# Processing Record 31 of Set 6 | port lincoln
# Processing Record 32 of Set 6 | yar-sale
# Processing Record 33 of Set 6 | ojinaga
# Processing Record 34 of Set 6 | sola
# Processing Record 35 of Set 6 | adrar
# Processing Record 36 of Set 6 | san-pedro
# Processing Record 37 of Set 6 | loudi
# Processing Record 38 of Set 6 | kibala
# Processing Record 39 of Set 6 | suraabad
# Processing Record 40 of Set 6 | durango
# Processing Record 41 of Set 6 | yasnyy
# Processing Record 42 of Set 6 | saint-philippe
# Processing Record 43 of Set 6 | george
# Processing Record 44 of Set 6 | tefe
# Processing Record 45 of Set 6 | milkovo
# Processing Record 46 of Set 6 | severo-kurilsk
# Processing Record 47 of Set 6 | khatanga
# Processing Record 48 of Set 6 | hamilton
# Processing Record 49 of Set 6 | sarandi
# Processing Record 50 of Set 6 | reforma
# Processing Record 1 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 2 of Set 7 | laramie
# Processing Record 3 of Set 7 | shizunai
# Processing Record 4 of Set 7 | okhotsk
# Processing Record 5 of Set 7 | toftir
# City not found. Skipping...
# Processing Record 6 of Set 7 | stanley
# Processing Record 7 of Set 7 | karamay
# City not found. Skipping...
# Processing Record 8 of Set 7 | cajamarca
# Processing Record 9 of Set 7 | vao
# Processing Record 10 of Set 7 | taoudenni
# Processing Record 11 of Set 7 | maridi
# Processing Record 12 of Set 7 | yoichi
# Processing Record 13 of Set 7 | unity
# Processing Record 14 of Set 7 | galiwinku
# City not found. Skipping...
# Processing Record 15 of Set 7 | yanam
# Processing Record 16 of Set 7 | mount gambier
# Processing Record 17 of Set 7 | brae
# Processing Record 18 of Set 7 | norwich
# Processing Record 19 of Set 7 | anadyr
# Processing Record 20 of Set 7 | magnitka
# Processing Record 21 of Set 7 | baie du tombeau
# City not found. Skipping...
# Processing Record 22 of Set 7 | teya
# Processing Record 23 of Set 7 | vryburg
# Processing Record 24 of Set 7 | belyy yar
# Processing Record 25 of Set 7 | hithadhoo
# Processing Record 26 of Set 7 | faanui
# Processing Record 27 of Set 7 | solovetskiy
# City not found. Skipping...
# Processing Record 28 of Set 7 | havoysund
# Processing Record 29 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 30 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 7 | hami
# Processing Record 32 of Set 7 | olga
# Processing Record 33 of Set 7 | hameln
# Processing Record 34 of Set 7 | krasnoselkup
# Processing Record 35 of Set 7 | nara
# Processing Record 36 of Set 7 | iqaluit
# Processing Record 37 of Set 7 | zachagansk
# City not found. Skipping...
# Processing Record 38 of Set 7 | rawson
# Processing Record 39 of Set 7 | sao joao da barra
# Processing Record 40 of Set 7 | bonavista
# Processing Record 41 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 7 | pipri
# Processing Record 43 of Set 7 | carahue
# Processing Record 44 of Set 7 | carnarvon
# Processing Record 45 of Set 7 | touros
# Processing Record 46 of Set 7 | sayyan
# Processing Record 47 of Set 7 | mitu
# Processing Record 48 of Set 7 | neiafu
# Processing Record 49 of Set 7 | alice springs
# Processing Record 50 of Set 7 | guanica
# Processing Record 1 of Set 8 | praia da vitoria
# Processing Record 2 of Set 8 | magdagachi
# Processing Record 3 of Set 8 | beihai
# Processing Record 4 of Set 8 | oriximina
# Processing Record 5 of Set 8 | jieshi
# Processing Record 6 of Set 8 | subtanjalla
# Processing Record 7 of Set 8 | komsomolskiy
# Processing Record 8 of Set 8 | vallenar
# Processing Record 9 of Set 8 | puerto del rosario
# Processing Record 10 of Set 8 | omboue
# Processing Record 11 of Set 8 | constitucion
# Processing Record 12 of Set 8 | lagoa
# Processing Record 13 of Set 8 | mangit
# Processing Record 14 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 15 of Set 8 | antalaha
# Processing Record 16 of Set 8 | nuuk
# Processing Record 17 of Set 8 | xaxim
# Processing Record 18 of Set 8 | upernavik
# Processing Record 19 of Set 8 | odweyne
# Processing Record 20 of Set 8 | yeppoon
# Processing Record 21 of Set 8 | santa rosalia
# Processing Record 22 of Set 8 | stokmarknes
# Processing Record 23 of Set 8 | hobyo
# Processing Record 24 of Set 8 | dianopolis
# City not found. Skipping...
# Processing Record 25 of Set 8 | hailey
# Processing Record 26 of Set 8 | souillac
# Processing Record 27 of Set 8 | nouadhibou
# Processing Record 28 of Set 8 | naze
# Processing Record 29 of Set 8 | kushikino
# Processing Record 30 of Set 8 | nhulunbuy
# Processing Record 31 of Set 8 | la ronge
# Processing Record 32 of Set 8 | isangel
# Processing Record 33 of Set 8 | balikpapan
# Processing Record 34 of Set 8 | boguchar
# Processing Record 35 of Set 8 | hatillo
# Processing Record 36 of Set 8 | jasper
# Processing Record 37 of Set 8 | cockburn town
# Processing Record 38 of Set 8 | nioro
# Processing Record 39 of Set 8 | lamar
# Processing Record 40 of Set 8 | cozumel
# Processing Record 41 of Set 8 | mayma
# Processing Record 42 of Set 8 | olinda
# Processing Record 43 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 8 | saldanha
# Processing Record 45 of Set 8 | shingu
# Processing Record 46 of Set 8 | tessalit
# Processing Record 47 of Set 8 | ketchikan
# Processing Record 48 of Set 8 | gisborne
# Processing Record 49 of Set 8 | fantino
# Processing Record 50 of Set 8 | puerto escondido
# Processing Record 1 of Set 9 | hanyang
# Processing Record 2 of Set 9 | rovinj
# Processing Record 3 of Set 9 | tashtyp
# Processing Record 4 of Set 9 | lompoc
# Processing Record 5 of Set 9 | vestmannaeyjar
# Processing Record 6 of Set 9 | klyuchi
# Processing Record 7 of Set 9 | oak ridge
# Processing Record 8 of Set 9 | bilma
# Processing Record 9 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 10 of Set 9 | puno
# Processing Record 11 of Set 9 | namibe
# Processing Record 12 of Set 9 | keti bandar
# Processing Record 13 of Set 9 | kloulklubed
# Processing Record 14 of Set 9 | masty
# Processing Record 15 of Set 9 | grindavik
# Processing Record 16 of Set 9 | natal
# Processing Record 17 of Set 9 | dillon
# Processing Record 18 of Set 9 | acarau
# Processing Record 19 of Set 9 | papara
# Processing Record 20 of Set 9 | biskamzha
# Processing Record 21 of Set 9 | isla vista
# Processing Record 22 of Set 9 | saint-joseph
# Processing Record 23 of Set 9 | dawlatabad
# Processing Record 24 of Set 9 | camana
# Processing Record 25 of Set 9 | siquijor
# Processing Record 26 of Set 9 | dangara
# Processing Record 27 of Set 9 | peace river
# Processing Record 28 of Set 9 | orchard homes
# Processing Record 29 of Set 9 | oktyabrskiy
# Processing Record 30 of Set 9 | barra do bugres
# Processing Record 31 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 32 of Set 9 | yuci
# Processing Record 33 of Set 9 | luganville
# Processing Record 34 of Set 9 | shiloh
# Processing Record 35 of Set 9 | tucurui
# Processing Record 36 of Set 9 | south valley
# Processing Record 37 of Set 9 | lerdo
# Processing Record 38 of Set 9 | asosa
# Processing Record 39 of Set 9 | isakly
# Processing Record 40 of Set 9 | canon city
# Processing Record 41 of Set 9 | chumikan
# Processing Record 42 of Set 9 | zlitan
# Processing Record 43 of Set 9 | lac du bonnet
# Processing Record 44 of Set 9 | guaymas
# Processing Record 45 of Set 9 | olafsvik
# Processing Record 46 of Set 9 | cayenne
# Processing Record 47 of Set 9 | makakilo city
# Processing Record 48 of Set 9 | ajaccio
# Processing Record 49 of Set 9 | batticaloa
# Processing Record 50 of Set 9 | alpena
# Processing Record 1 of Set 10 | berlevag
# Processing Record 2 of Set 10 | labuan
# Processing Record 3 of Set 10 | guilin
# Processing Record 4 of Set 10 | ust-nera
# Processing Record 5 of Set 10 | ambilobe
# Processing Record 6 of Set 10 | seymchan
# Processing Record 7 of Set 10 | caceres
# Processing Record 8 of Set 10 | hofn
# Processing Record 9 of Set 10 | staryy nadym
# Processing Record 10 of Set 10 | lorengau
# Processing Record 11 of Set 10 | tiarei
# Processing Record 12 of Set 10 | bereda
# Processing Record 13 of Set 10 | mnogovershinnyy
# Processing Record 14 of Set 10 | sorong
# Processing Record 15 of Set 10 | broome
# Processing Record 16 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 10 | poum
# Processing Record 18 of Set 10 | imbituba
# Processing Record 19 of Set 10 | limbuhan
# Processing Record 20 of Set 10 | shimoda
# Processing Record 21 of Set 10 | veinticinco de mayo
# Processing Record 22 of Set 10 | bodden town
# Processing Record 23 of Set 10 | bestobe
# Processing Record 24 of Set 10 | dicabisagan
# Processing Record 25 of Set 10 | necochea
# Processing Record 26 of Set 10 | timra
# Processing Record 27 of Set 10 | mahibadhoo
# Processing Record 28 of Set 10 | malakal
# Processing Record 29 of Set 10 | cocobeach
# Processing Record 30 of Set 10 | erenhot
# Processing Record 31 of Set 10 | haines junction
# Processing Record 32 of Set 10 | utkivka
# Processing Record 33 of Set 10 | muncar
# Processing Record 34 of Set 10 | vardo
# Processing Record 35 of Set 10 | dongkan
# Processing Record 36 of Set 10 | sault sainte marie
# Processing Record 37 of Set 10 | kaitangata
# Processing Record 38 of Set 10 | sitka
# Processing Record 39 of Set 10 | shenjiamen
# Processing Record 40 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 41 of Set 10 | dickinson
# Processing Record 42 of Set 10 | toyooka
# Processing Record 43 of Set 10 | xingyi
# Processing Record 44 of Set 10 | deputatskiy
# Processing Record 45 of Set 10 | maldonado
# Processing Record 46 of Set 10 | chornyanka
# Processing Record 47 of Set 10 | san felipe
# Processing Record 48 of Set 10 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 49 of Set 10 | concepcion
# Processing Record 50 of Set 10 | kadyy
# Processing Record 1 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 2 of Set 11 | valleyview
# Processing Record 3 of Set 11 | awbari
# Processing Record 4 of Set 11 | seoul
# Processing Record 5 of Set 11 | ulaangom
# Processing Record 6 of Set 11 | biankouma
# Processing Record 7 of Set 11 | qafsah
# City not found. Skipping...
# Processing Record 8 of Set 11 | banmo
# City not found. Skipping...
# Processing Record 9 of Set 11 | kalcheva
# Processing Record 10 of Set 11 | emerald
# Processing Record 11 of Set 11 | tabuk
# Processing Record 12 of Set 11 | athabasca
# Processing Record 13 of Set 11 | bubaque
# Processing Record 14 of Set 11 | vostok
# Processing Record 15 of Set 11 | grand gaube
# Processing Record 16 of Set 11 | pecos
# Processing Record 17 of Set 11 | raudeberg
# Processing Record 18 of Set 11 | hualmay
# Processing Record 19 of Set 11 | shasta lake
# Processing Record 20 of Set 11 | huron
# Processing Record 21 of Set 11 | marienburg
# Processing Record 22 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 11 | ust-ordynskiy
# Processing Record 24 of Set 11 | columbia
# Processing Record 25 of Set 11 | maesteg
# Processing Record 26 of Set 11 | harper
# Processing Record 27 of Set 11 | elat
# Processing Record 28 of Set 11 | armenia
# Processing Record 29 of Set 11 | naantali
# Processing Record 30 of Set 11 | tarakan
# Processing Record 31 of Set 11 | sarangani
# Processing Record 32 of Set 11 | burnie
# Processing Record 33 of Set 11 | ugoofaaru
# Processing Record 34 of Set 11 | podporozhye
# Processing Record 35 of Set 11 | sedelnikovo
# City not found. Skipping...
# Processing Record 36 of Set 11 | beidao
# Processing Record 37 of Set 11 | linhares
# Processing Record 38 of Set 11 | sikasso
# Processing Record 39 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 40 of Set 11 | bonfim
# Processing Record 41 of Set 11 | alappuzha
# Processing Record 42 of Set 11 | ambon
# Processing Record 43 of Set 11 | matadi
# Processing Record 44 of Set 11 | springbok
# Processing Record 45 of Set 11 | guilford
# Processing Record 46 of Set 11 | devils lake
# Processing Record 47 of Set 11 | barra
# Processing Record 48 of Set 11 | karasjok
# Processing Record 49 of Set 11 | garden city
# Processing Record 50 of Set 11 | oranjemund
# Processing Record 1 of Set 12 | lar gerd
# City not found. Skipping...
# Processing Record 2 of Set 12 | cape coast
# Processing Record 3 of Set 12 | verkhnyaya maksakovka
# Processing Record 4 of Set 12 | dakar
# Processing Record 5 of Set 12 | dutse
# Processing Record 6 of Set 12 | shiyan
# Processing Record 7 of Set 12 | nador
# Processing Record 8 of Set 12 | tondon
# Processing Record 9 of Set 12 | savannah bight
# Processing Record 10 of Set 12 | watsa
# Processing Record 11 of Set 12 | evanston
# Processing Record 12 of Set 12 | tomohon
# Processing Record 13 of Set 12 | udachnyy
# Processing Record 14 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 15 of Set 12 | bantry
# Processing Record 16 of Set 12 | gubkinskiy
# Processing Record 17 of Set 12 | nyamati
# Processing Record 18 of Set 12 | bearsden
# Processing Record 19 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 20 of Set 12 | novo aripuana
# Processing Record 21 of Set 12 | eydhafushi
# Processing Record 22 of Set 12 | viedma
# Processing Record 23 of Set 12 | albanel
# Processing Record 24 of Set 12 | tuatapere
# Processing Record 25 of Set 12 | qujing
# Processing Record 26 of Set 12 | naron
# Processing Record 27 of Set 12 | ossora
# Processing Record 28 of Set 12 | kununurra
# Processing Record 29 of Set 12 | ulladulla
# Processing Record 30 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 31 of Set 12 | wajir
# Processing Record 32 of Set 12 | mahon
# Processing Record 33 of Set 12 | tomatlan
# Processing Record 34 of Set 12 | uzumlu
# City not found. Skipping...
# Processing Record 35 of Set 12 | livramento
# Processing Record 36 of Set 12 | tyachiv
# Processing Record 37 of Set 12 | buala
# Processing Record 38 of Set 12 | stepnoye
# Processing Record 39 of Set 12 | yekaterinoslavka
# Processing Record 40 of Set 12 | qaqortoq
# Processing Record 41 of Set 12 | zhigansk
# Processing Record 42 of Set 12 | maragogi
# Processing Record 43 of Set 12 | santa cruz
# Processing Record 44 of Set 12 | hay river
# Processing Record 45 of Set 12 | vaitape
# Processing Record 46 of Set 12 | sivaki
# Processing Record 47 of Set 12 | ikere
# Processing Record 48 of Set 12 | leshukonskoye
# Processing Record 49 of Set 12 | zelenogorskiy
# Processing Record 50 of Set 12 | panjab
# Processing Record 1 of Set 13 | wokha
# Processing Record 2 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 3 of Set 13 | tarauaca
# Processing Record 4 of Set 13 | juneau
# Processing Record 5 of Set 13 | novobirilyussy
# Processing Record 6 of Set 13 | sun valley
# Processing Record 7 of Set 13 | binga
# Processing Record 8 of Set 13 | chapais
# Processing Record 9 of Set 13 | broken hill
# Processing Record 10 of Set 13 | oussouye
# Processing Record 11 of Set 13 | tavricheskoye
# Processing Record 12 of Set 13 | todos santos
# Processing Record 13 of Set 13 | charleston
# Processing Record 14 of Set 13 | shitanjing
# Processing Record 15 of Set 13 | canto do buriti
# Processing Record 16 of Set 13 | cap malheureux
# Processing Record 17 of Set 13 | adre
# Processing Record 18 of Set 13 | moramanga
# Processing Record 19 of Set 13 | farafangana
# Processing Record 20 of Set 13 | trujillo
# Processing Record 21 of Set 13 | llata
# Processing Record 22 of Set 13 | biscarrosse
# Processing Record 23 of Set 13 | lyndon
# Processing Record 24 of Set 13 | sakaraha
# Processing Record 25 of Set 13 | vangaindrano
# Processing Record 26 of Set 13 | ercis
# Processing Record 27 of Set 13 | beisfjord
# Processing Record 28 of Set 13 | san carlos
# Processing Record 29 of Set 13 | kostomuksha
# Processing Record 30 of Set 13 | liverpool
# Processing Record 31 of Set 13 | san patricio
# Processing Record 32 of Set 13 | tautira
# Processing Record 33 of Set 13 | talnakh
# Processing Record 34 of Set 13 | san andres
# Processing Record 35 of Set 13 | roald
# Processing Record 36 of Set 13 | karasburg
# Processing Record 37 of Set 13 | saint-francois
# Processing Record 38 of Set 13 | ouricuri
# Processing Record 39 of Set 13 | ati
# Processing Record 40 of Set 13 | rincon
# Processing Record 41 of Set 13 | baruun-urt
# Processing Record 42 of Set 13 | harrisonburg
# Processing Record 43 of Set 13 | dubti
# Processing Record 44 of Set 13 | sur
# Processing Record 45 of Set 13 | dabhol
# Processing Record 46 of Set 13 | kalabo
# Processing Record 47 of Set 13 | nome
# Processing Record 48 of Set 13 | jaypur
# Processing Record 49 of Set 13 | boca do acre
# Processing Record 50 of Set 13 | inuvik
# Processing Record 1 of Set 14 | avila
# Processing Record 2 of Set 14 | yarada
# Processing Record 3 of Set 14 | rabo de peixe
# Processing Record 4 of Set 14 | macaboboni
# City not found. Skipping...
# Processing Record 5 of Set 14 | the valley
# Processing Record 6 of Set 14 | emet
# Processing Record 7 of Set 14 | alta floresta
# Processing Record 8 of Set 14 | verkhovazhye
# Processing Record 9 of Set 14 | botngard
# Processing Record 10 of Set 14 | katherine
# Processing Record 11 of Set 14 | inirida
# Processing Record 12 of Set 14 | cuajinicuilapa
# Processing Record 13 of Set 14 | dharchula
# Processing Record 14 of Set 14 | houma
# Processing Record 15 of Set 14 | cukai
# Processing Record 16 of Set 14 | vanimo
# Processing Record 17 of Set 14 | kidal
# Processing Record 18 of Set 14 | pangnirtung
# Processing Record 19 of Set 14 | trat
# Processing Record 20 of Set 14 | quzhou
# Processing Record 21 of Set 14 | vilhena
# Processing Record 22 of Set 14 | concepcion del oro
# Processing Record 23 of Set 14 | tshikapa
# Processing Record 24 of Set 14 | kayanga
# Processing Record 25 of Set 14 | sawtell
# Processing Record 26 of Set 14 | perth
# Processing Record 27 of Set 14 | smoky lake
# Processing Record 28 of Set 14 | riyaq
# City not found. Skipping...
# Processing Record 29 of Set 14 | bajil
# Processing Record 30 of Set 14 | jabiru
# City not found. Skipping...
# Processing Record 31 of Set 14 | oum hadjer
# Processing Record 32 of Set 14 | bangassou
# Processing Record 33 of Set 14 | kawalu
# Processing Record 34 of Set 14 | copiapo
# Processing Record 35 of Set 14 | van
# Processing Record 36 of Set 14 | ovsyanka
# Processing Record 37 of Set 14 | donduseni
# Processing Record 38 of Set 14 | portage
# Processing Record 39 of Set 14 | moranbah
# Processing Record 40 of Set 14 | mokrousovo
# Processing Record 41 of Set 14 | calama
# Processing Record 42 of Set 14 | ahipara
# Processing Record 43 of Set 14 | bocas del toro
# Processing Record 44 of Set 14 | boyolangu
# Processing Record 45 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 46 of Set 14 | debre birhan
# Processing Record 47 of Set 14 | issenye
# Processing Record 48 of Set 14 | hetauda
# Processing Record 49 of Set 14 | vredendal
# Processing Record 50 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 1 of Set 15 | bayan
# Processing Record 2 of Set 15 | san quintin
# Processing Record 3 of Set 15 | andenes
# Processing Record 4 of Set 15 | kolpashevo
# Processing Record 5 of Set 15 | whitehorse
# Processing Record 6 of Set 15 | ponta delgada
# Processing Record 7 of Set 15 | doha
# Processing Record 8 of Set 15 | suluq
# Processing Record 9 of Set 15 | krasnyy mayak
# City not found. Skipping...
# Processing Record 10 of Set 15 | lamu
# Processing Record 11 of Set 15 | powell
# Processing Record 12 of Set 15 | amapa
# Processing Record 13 of Set 15 | qingdao
# Processing Record 14 of Set 15 | manali
# Processing Record 15 of Set 15 | kerema
# Processing Record 16 of Set 15 | dali
# Processing Record 17 of Set 15 | derzhavinsk
# Processing Record 18 of Set 15 | winslow
# Processing Record 19 of Set 15 | save
# Processing Record 20 of Set 15 | jumla
# Processing Record 21 of Set 15 | kyzyl-mazhalyk
# Processing Record 22 of Set 15 | muyezerskiy
# Processing Record 23 of Set 15 | mayo
# Processing Record 24 of Set 15 | ginir
# Processing Record 25 of Set 15 | lakes entrance
# Processing Record 26 of Set 15 | balakhta
# Processing Record 27 of Set 15 | agirish
# Processing Record 28 of Set 15 | tostamaa
# City not found. Skipping...
# Processing Record 29 of Set 15 | manado
# Processing Record 30 of Set 15 | maarianhamina
# Processing Record 31 of Set 15 | bacolod
# Processing Record 32 of Set 15 | tetouan
# Processing Record 33 of Set 15 | college
# Processing Record 34 of Set 15 | linxia
# Processing Record 35 of Set 15 | san jeronimo
# Processing Record 36 of Set 15 | la macarena
# Processing Record 37 of Set 15 | muros
# Processing Record 38 of Set 15 | we
# City not found. Skipping...
# Processing Record 39 of Set 15 | shieli
# Processing Record 40 of Set 15 | tahta
# Processing Record 41 of Set 15 | sinnamary
# Processing Record 42 of Set 15 | karmaskaly
# Processing Record 43 of Set 15 | hauterive
# Processing Record 44 of Set 15 | alsip
# Processing Record 45 of Set 15 | noumea
# Processing Record 46 of Set 15 | twin falls
# Processing Record 47 of Set 15 | maua
# Processing Record 48 of Set 15 | kaeo
# Processing Record 49 of Set 15 | miandrivazo
# Processing Record 50 of Set 15 | tartus
# Processing Record 1 of Set 16 | manitouwadge
# Processing Record 2 of Set 16 | nizhnevartovsk
# Processing Record 3 of Set 16 | sol-iletsk
# Processing Record 4 of Set 16 | martapura
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Khovu-Aksy  51.1333   93.6000     31.03        77         100        4.14
# 1       Vaini -21.2000 -175.2000     78.96        83          20       11.50
# 2      Albany  42.6001  -73.9662     57.38        92          95        2.44
# 3     Rexburg  43.8260 -111.7897     60.06        58           1        5.75
# 4   Busselton -33.6500  115.3333     49.05        83          95        4.29
# 5     Mataura -46.1927  168.8643     48.25        97         100       14.07
# 6     Qaanaaq  77.4840  -69.3632      2.21        54           0        7.85
# 7       Pevek  69.7008  170.3133     -2.78        96         100       10.63
# 8       Dukat  62.5500  155.5500     -1.52        95         100        4.27
# 9   Egvekinot  66.3167 -179.1667      2.89        91         100        9.93
#
#        Description
# 0  overcast clouds
# 1       few clouds
# 2  overcast clouds
# 3        clear sky
# 4  overcast clouds
# 5  overcast clouds
# 6        clear sky
# 7  overcast clouds
# 8  overcast clouds
# 9  overcast clouds

# %%
#create the output file (csv)
output_data_file = "Weather_Database.cvs"
#export the city_data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
