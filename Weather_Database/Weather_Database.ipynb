# %%
#import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from citipy import citipy
import requests
from datetime import datetime 
from config import weather_api_key

# %%
#create a new set of random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
coordinates = zip(lats,lngs)
coordinates

# %%
#add the coordinates to a list
coordinates = list(coordinates)

# %%
#get the nearest city using the citipy module
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 733

# %%
#perform an API call with the OpenWeatherMap
city_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#retrieve information from the API call.

#create an empty list to hold the weather data
city_data = []
#print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
#create counters.
record_count = 1
set_count = 1

#loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city.
    url = city_url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(url).json()
        # Parse out the needed data.
        city_country = city_weather['sys']['country']
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_wdesc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country":city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_wdesc})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | east london
# Processing Record 2 of Set 1 | thompson
# Processing Record 3 of Set 1 | colares
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | codrington
# Processing Record 7 of Set 1 | babu
# Processing Record 8 of Set 1 | touros
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | qom
# Processing Record 11 of Set 1 | deputatskiy
# Processing Record 12 of Set 1 | bluff
# Processing Record 13 of Set 1 | bethel
# Processing Record 14 of Set 1 | port alfred
# Processing Record 15 of Set 1 | paragominas
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 1 | tuatapere
# Processing Record 19 of Set 1 | sambava
# Processing Record 20 of Set 1 | port blair
# Processing Record 21 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 1 | paamiut
# Processing Record 23 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 1 | mar del plata
# Processing Record 25 of Set 1 | avera
# Processing Record 26 of Set 1 | chokurdakh
# Processing Record 27 of Set 1 | jiroft
# City not found. Skipping...
# Processing Record 28 of Set 1 | lebu
# Processing Record 29 of Set 1 | callaway
# Processing Record 30 of Set 1 | auki
# Processing Record 31 of Set 1 | mount isa
# Processing Record 32 of Set 1 | zurrieq
# Processing Record 33 of Set 1 | bouna
# Processing Record 34 of Set 1 | jamestown
# Processing Record 35 of Set 1 | pevek
# Processing Record 36 of Set 1 | dikson
# Processing Record 37 of Set 1 | byron bay
# Processing Record 38 of Set 1 | kavieng
# Processing Record 39 of Set 1 | sao filipe
# Processing Record 40 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 1 | bambous virieux
# Processing Record 42 of Set 1 | virginia beach
# Processing Record 43 of Set 1 | kamenka
# Processing Record 44 of Set 1 | porto novo
# Processing Record 45 of Set 1 | cidreira
# Processing Record 46 of Set 1 | galgani
# City not found. Skipping...
# Processing Record 47 of Set 1 | nikolskoye
# Processing Record 48 of Set 1 | dunedin
# Processing Record 49 of Set 1 | bat khela
# Processing Record 50 of Set 1 | belaya gora
# Processing Record 1 of Set 2 | vila velha
# Processing Record 2 of Set 2 | constitucion
# Processing Record 3 of Set 2 | gewane
# Processing Record 4 of Set 2 | rikitea
# Processing Record 5 of Set 2 | norman wells
# Processing Record 6 of Set 2 | paranga
# Processing Record 7 of Set 2 | bathsheba
# Processing Record 8 of Set 2 | olafsvik
# Processing Record 9 of Set 2 | boa vista
# Processing Record 10 of Set 2 | vaini
# Processing Record 11 of Set 2 | saint-philippe
# Processing Record 12 of Set 2 | remiremont
# Processing Record 13 of Set 2 | paradwip
# City not found. Skipping...
# Processing Record 14 of Set 2 | port elizabeth
# Processing Record 15 of Set 2 | manzanillo
# Processing Record 16 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 2 | bengkulu
# Processing Record 18 of Set 2 | georgetown
# Processing Record 19 of Set 2 | yellowknife
# Processing Record 20 of Set 2 | castro
# Processing Record 21 of Set 2 | abbeyfeale
# Processing Record 22 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 23 of Set 2 | kisangani
# Processing Record 24 of Set 2 | gemena
# Processing Record 25 of Set 2 | ancud
# Processing Record 26 of Set 2 | gurgan
# City not found. Skipping...
# Processing Record 27 of Set 2 | guelengdeng
# City not found. Skipping...
# Processing Record 28 of Set 2 | airai
# Processing Record 29 of Set 2 | kathmandu
# Processing Record 30 of Set 2 | avarua
# Processing Record 31 of Set 2 | luderitz
# Processing Record 32 of Set 2 | sur
# Processing Record 33 of Set 2 | vilhena
# Processing Record 34 of Set 2 | hilo
# Processing Record 35 of Set 2 | thinadhoo
# Processing Record 36 of Set 2 | dronten
# Processing Record 37 of Set 2 | butaritari
# Processing Record 38 of Set 2 | dingzhou
# Processing Record 39 of Set 2 | sitka
# Processing Record 40 of Set 2 | ust-nera
# Processing Record 41 of Set 2 | kapaa
# Processing Record 42 of Set 2 | bokspits
# City not found. Skipping...
# Processing Record 43 of Set 2 | new norfolk
# Processing Record 44 of Set 2 | addi ugri
# City not found. Skipping...
# Processing Record 45 of Set 2 | phan rang
# City not found. Skipping...
# Processing Record 46 of Set 2 | ponta do sol
# Processing Record 47 of Set 2 | asnaes
# Processing Record 48 of Set 2 | hermanus
# Processing Record 49 of Set 2 | bemidji
# Processing Record 50 of Set 2 | isangel
# Processing Record 1 of Set 3 | ballina
# Processing Record 2 of Set 3 | fort nelson
# Processing Record 3 of Set 3 | saldanha
# Processing Record 4 of Set 3 | kaitangata
# Processing Record 5 of Set 3 | necochea
# Processing Record 6 of Set 3 | kahului
# Processing Record 7 of Set 3 | san buenaventura
# Processing Record 8 of Set 3 | linchuan
# City not found. Skipping...
# Processing Record 9 of Set 3 | port hardy
# Processing Record 10 of Set 3 | severo-kurilsk
# Processing Record 11 of Set 3 | brigantine
# Processing Record 12 of Set 3 | albany
# Processing Record 13 of Set 3 | izacic
# Processing Record 14 of Set 3 | oranjemund
# Processing Record 15 of Set 3 | port macquarie
# Processing Record 16 of Set 3 | qaanaaq
# Processing Record 17 of Set 3 | mount gambier
# Processing Record 18 of Set 3 | channel-port aux basques
# Processing Record 19 of Set 3 | lompoc
# Processing Record 20 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 3 | san quintin
# Processing Record 22 of Set 3 | rajanpur
# Processing Record 23 of Set 3 | inhambane
# Processing Record 24 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 25 of Set 3 | pangnirtung
# Processing Record 26 of Set 3 | phalombe
# Processing Record 27 of Set 3 | nemuro
# Processing Record 28 of Set 3 | keti bandar
# Processing Record 29 of Set 3 | yerbogachen
# Processing Record 30 of Set 3 | los llanos de aridane
# Processing Record 31 of Set 3 | asilah
# Processing Record 32 of Set 3 | margate
# Processing Record 33 of Set 3 | nanortalik
# Processing Record 34 of Set 3 | berdigestyakh
# Processing Record 35 of Set 3 | saint george
# Processing Record 36 of Set 3 | barabai
# Processing Record 37 of Set 3 | hamilton
# Processing Record 38 of Set 3 | goianesia
# Processing Record 39 of Set 3 | tuktoyaktuk
# Processing Record 40 of Set 3 | palestine
# Processing Record 41 of Set 3 | tilichiki
# Processing Record 42 of Set 3 | kruisfontein
# Processing Record 43 of Set 3 | walvis bay
# Processing Record 44 of Set 3 | baoqing
# Processing Record 45 of Set 3 | lewiston
# Processing Record 46 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 47 of Set 3 | pisco
# Processing Record 48 of Set 3 | south venice
# Processing Record 49 of Set 3 | salta
# Processing Record 50 of Set 3 | haines junction
# Processing Record 1 of Set 4 | voznesenye
# Processing Record 2 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 4 | leningradskiy
# Processing Record 4 of Set 4 | rio gallegos
# Processing Record 5 of Set 4 | ilulissat
# Processing Record 6 of Set 4 | longyearbyen
# Processing Record 7 of Set 4 | puerto ayora
# Processing Record 8 of Set 4 | comodoro rivadavia
# Processing Record 9 of Set 4 | khatanga
# Processing Record 10 of Set 4 | lata
# Processing Record 11 of Set 4 | vagur
# Processing Record 12 of Set 4 | kamyshin
# Processing Record 13 of Set 4 | muscat
# Processing Record 14 of Set 4 | cape town
# Processing Record 15 of Set 4 | haradok
# Processing Record 16 of Set 4 | bredasdorp
# Processing Record 17 of Set 4 | lodja
# Processing Record 18 of Set 4 | ostrovnoy
# Processing Record 19 of Set 4 | hobart
# Processing Record 20 of Set 4 | tiksi
# Processing Record 21 of Set 4 | lannion
# Processing Record 22 of Set 4 | acapulco
# Processing Record 23 of Set 4 | san cristobal
# Processing Record 24 of Set 4 | ribeira grande
# Processing Record 25 of Set 4 | sioux lookout
# Processing Record 26 of Set 4 | nizhniy odes
# Processing Record 27 of Set 4 | cururupu
# Processing Record 28 of Set 4 | north bend
# Processing Record 29 of Set 4 | yaya
# Processing Record 30 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 4 | kavaratti
# Processing Record 32 of Set 4 | maua
# Processing Record 33 of Set 4 | mahebourg
# Processing Record 34 of Set 4 | bandarbeyla
# Processing Record 35 of Set 4 | honiara
# Processing Record 36 of Set 4 | emba
# Processing Record 37 of Set 4 | ende
# Processing Record 38 of Set 4 | kununurra
# Processing Record 39 of Set 4 | jiayuguan
# Processing Record 40 of Set 4 | hithadhoo
# Processing Record 41 of Set 4 | atuona
# Processing Record 42 of Set 4 | sinnamary
# Processing Record 43 of Set 4 | qasigiannguit
# Processing Record 44 of Set 4 | baykit
# Processing Record 45 of Set 4 | kikwit
# Processing Record 46 of Set 4 | saskylakh
# Processing Record 47 of Set 4 | hofn
# Processing Record 48 of Set 4 | portland
# Processing Record 49 of Set 4 | valdez
# Processing Record 50 of Set 4 | silvan
# Processing Record 1 of Set 5 | chapais
# Processing Record 2 of Set 5 | hasaki
# Processing Record 3 of Set 5 | lagoa
# Processing Record 4 of Set 5 | umkomaas
# Processing Record 5 of Set 5 | hagdan
# Processing Record 6 of Set 5 | yakeshi
# Processing Record 7 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 8 of Set 5 | bogense
# Processing Record 9 of Set 5 | fortuna
# Processing Record 10 of Set 5 | tidore
# City not found. Skipping...
# Processing Record 11 of Set 5 | coihaique
# Processing Record 12 of Set 5 | kodiak
# Processing Record 13 of Set 5 | yumen
# Processing Record 14 of Set 5 | dryden
# Processing Record 15 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 16 of Set 5 | tasbuget
# City not found. Skipping...
# Processing Record 17 of Set 5 | asau
# Processing Record 18 of Set 5 | tahta
# Processing Record 19 of Set 5 | port hawkesbury
# Processing Record 20 of Set 5 | barra do garcas
# Processing Record 21 of Set 5 | carnarvon
# Processing Record 22 of Set 5 | sungai padi
# Processing Record 23 of Set 5 | teguise
# Processing Record 24 of Set 5 | jackson
# Processing Record 25 of Set 5 | te anau
# Processing Record 26 of Set 5 | goderich
# Processing Record 27 of Set 5 | adrar
# Processing Record 28 of Set 5 | xichang
# Processing Record 29 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 5 | nantucket
# Processing Record 31 of Set 5 | casas grandes
# Processing Record 32 of Set 5 | roswell
# Processing Record 33 of Set 5 | kabale
# Processing Record 34 of Set 5 | roanoke rapids
# Processing Record 35 of Set 5 | padang
# Processing Record 36 of Set 5 | koulamoutou
# Processing Record 37 of Set 5 | puerto palomas
# Processing Record 38 of Set 5 | lodwar
# Processing Record 39 of Set 5 | den helder
# Processing Record 40 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 41 of Set 5 | cherskiy
# Processing Record 42 of Set 5 | high level
# Processing Record 43 of Set 5 | pangody
# Processing Record 44 of Set 5 | praia da vitoria
# Processing Record 45 of Set 5 | champerico
# Processing Record 46 of Set 5 | alice springs
# Processing Record 47 of Set 5 | iqaluit
# Processing Record 48 of Set 5 | buluang
# Processing Record 49 of Set 5 | domoni
# Processing Record 50 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 6 | clyde river
# Processing Record 2 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 3 of Set 6 | carballo
# Processing Record 4 of Set 6 | srednekolymsk
# Processing Record 5 of Set 6 | nong khai
# Processing Record 6 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 7 of Set 6 | mandalgovi
# Processing Record 8 of Set 6 | bilibino
# Processing Record 9 of Set 6 | san policarpo
# Processing Record 10 of Set 6 | sicamous
# Processing Record 11 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 6 | abatskoye
# Processing Record 13 of Set 6 | reconquista
# Processing Record 14 of Set 6 | port lincoln
# Processing Record 15 of Set 6 | xam nua
# Processing Record 16 of Set 6 | gazanjyk
# Processing Record 17 of Set 6 | praia
# Processing Record 18 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 6 | ekhabi
# Processing Record 20 of Set 6 | verkhnevilyuysk
# Processing Record 21 of Set 6 | camacha
# Processing Record 22 of Set 6 | katsuura
# Processing Record 23 of Set 6 | urozhaynoye
# Processing Record 24 of Set 6 | chuy
# Processing Record 25 of Set 6 | san juan
# Processing Record 26 of Set 6 | ranong
# Processing Record 27 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 6 | formoso do araguaia
# City not found. Skipping...
# Processing Record 29 of Set 6 | aktanysh
# Processing Record 30 of Set 6 | victoria
# Processing Record 31 of Set 6 | arraial do cabo
# Processing Record 32 of Set 6 | lafiagi
# Processing Record 33 of Set 6 | birnin kebbi
# Processing Record 34 of Set 6 | batagay-alyta
# Processing Record 35 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 36 of Set 6 | aksay
# Processing Record 37 of Set 6 | ciudad bolivar
# Processing Record 38 of Set 6 | verkhoyansk
# Processing Record 39 of Set 6 | wewak
# Processing Record 40 of Set 6 | birjand
# Processing Record 41 of Set 6 | kutulik
# Processing Record 42 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 6 | deer lake
# Processing Record 44 of Set 6 | atar
# Processing Record 45 of Set 6 | mancio lima
# Processing Record 46 of Set 6 | bindura
# Processing Record 47 of Set 6 | barrow
# Processing Record 48 of Set 6 | amberley
# Processing Record 49 of Set 6 | kuminskiy
# Processing Record 50 of Set 6 | souillac
# Processing Record 1 of Set 7 | meulaboh
# Processing Record 2 of Set 7 | hof
# Processing Record 3 of Set 7 | nurota
# Processing Record 4 of Set 7 | broome
# Processing Record 5 of Set 7 | ponta delgada
# Processing Record 6 of Set 7 | alofi
# Processing Record 7 of Set 7 | pitimbu
# Processing Record 8 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 7 | grindavik
# Processing Record 10 of Set 7 | faanui
# Processing Record 11 of Set 7 | upernavik
# Processing Record 12 of Set 7 | hervey bay
# Processing Record 13 of Set 7 | cockburn harbour
# City not found. Skipping...
# Processing Record 14 of Set 7 | vardo
# Processing Record 15 of Set 7 | caldwell
# Processing Record 16 of Set 7 | jishou
# Processing Record 17 of Set 7 | tsumeb
# Processing Record 18 of Set 7 | chifeng
# Processing Record 19 of Set 7 | kulhudhuffushi
# Processing Record 20 of Set 7 | koungou
# Processing Record 21 of Set 7 | narsaq
# Processing Record 22 of Set 7 | moa
# Processing Record 23 of Set 7 | manaure
# Processing Record 24 of Set 7 | emerald
# Processing Record 25 of Set 7 | senneterre
# Processing Record 26 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 27 of Set 7 | mitzic
# Processing Record 28 of Set 7 | brainerd
# Processing Record 29 of Set 7 | gao
# Processing Record 30 of Set 7 | port-gentil
# Processing Record 31 of Set 7 | myanaung
# Processing Record 32 of Set 7 | nouadhibou
# Processing Record 33 of Set 7 | quatre cocos
# Processing Record 34 of Set 7 | merauke
# Processing Record 35 of Set 7 | wangkui
# Processing Record 36 of Set 7 | nanning
# Processing Record 37 of Set 7 | okhotsk
# Processing Record 38 of Set 7 | bereda
# Processing Record 39 of Set 7 | arandis
# Processing Record 40 of Set 7 | bonavista
# Processing Record 41 of Set 7 | mehamn
# Processing Record 42 of Set 7 | paveh
# Processing Record 43 of Set 7 | gushikawa
# Processing Record 44 of Set 7 | arruda dos vinhos
# Processing Record 45 of Set 7 | beloha
# Processing Record 46 of Set 7 | geraldton
# Processing Record 47 of Set 7 | leshukonskoye
# Processing Record 48 of Set 7 | orsk
# Processing Record 49 of Set 7 | takoradi
# Processing Record 50 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 8 | braniewo
# Processing Record 2 of Set 8 | karamay
# City not found. Skipping...
# Processing Record 3 of Set 8 | barcelos
# Processing Record 4 of Set 8 | imbituba
# Processing Record 5 of Set 8 | leh
# Processing Record 6 of Set 8 | bend
# Processing Record 7 of Set 8 | angoche
# Processing Record 8 of Set 8 | dhidhdhoo
# Processing Record 9 of Set 8 | chunoyar
# Processing Record 10 of Set 8 | wahran
# City not found. Skipping...
# Processing Record 11 of Set 8 | lima
# Processing Record 12 of Set 8 | opotiki
# Processing Record 13 of Set 8 | sola
# Processing Record 14 of Set 8 | altay
# Processing Record 15 of Set 8 | darab
# Processing Record 16 of Set 8 | aasiaat
# Processing Record 17 of Set 8 | jalu
# Processing Record 18 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 19 of Set 8 | takaka
# Processing Record 20 of Set 8 | mehran
# Processing Record 21 of Set 8 | paducah
# Processing Record 22 of Set 8 | uwayl
# City not found. Skipping...
# Processing Record 23 of Set 8 | mlonggo
# Processing Record 24 of Set 8 | rock sound
# Processing Record 25 of Set 8 | provideniya
# Processing Record 26 of Set 8 | chinique
# Processing Record 27 of Set 8 | nolinsk
# Processing Record 28 of Set 8 | manado
# Processing Record 29 of Set 8 | dubbo
# Processing Record 30 of Set 8 | korla
# Processing Record 31 of Set 8 | kushima
# Processing Record 32 of Set 8 | mitsamiouli
# Processing Record 33 of Set 8 | guerrero negro
# Processing Record 34 of Set 8 | sakakah
# Processing Record 35 of Set 8 | bridlington
# Processing Record 36 of Set 8 | douglas
# Processing Record 37 of Set 8 | gravelbourg
# Processing Record 38 of Set 8 | tasiilaq
# Processing Record 39 of Set 8 | umm lajj
# Processing Record 40 of Set 8 | sao tome
# Processing Record 41 of Set 8 | boyolangu
# Processing Record 42 of Set 8 | novikovo
# Processing Record 43 of Set 8 | hami
# Processing Record 44 of Set 8 | geresk
# City not found. Skipping...
# Processing Record 45 of Set 8 | pimentel
# Processing Record 46 of Set 8 | ariano irpino
# Processing Record 47 of Set 8 | bairiki
# Processing Record 48 of Set 8 | chimbote
# Processing Record 49 of Set 8 | yar-sale
# Processing Record 50 of Set 8 | saquarema
# Processing Record 1 of Set 9 | moussoro
# Processing Record 2 of Set 9 | itarema
# Processing Record 3 of Set 9 | dingle
# Processing Record 4 of Set 9 | salalah
# Processing Record 5 of Set 9 | rocha
# Processing Record 6 of Set 9 | clearwater
# Processing Record 7 of Set 9 | arlit
# Processing Record 8 of Set 9 | pringsewu
# Processing Record 9 of Set 9 | darlawn
# Processing Record 10 of Set 9 | ambon
# Processing Record 11 of Set 9 | celestun
# Processing Record 12 of Set 9 | luanda
# Processing Record 13 of Set 9 | miranda
# Processing Record 14 of Set 9 | cabedelo
# Processing Record 15 of Set 9 | nova odesa
# Processing Record 16 of Set 9 | male
# Processing Record 17 of Set 9 | soe
# Processing Record 18 of Set 9 | lasa
# Processing Record 19 of Set 9 | mahbubnagar
# Processing Record 20 of Set 9 | midland
# Processing Record 21 of Set 9 | esperance
# Processing Record 22 of Set 9 | paita
# Processing Record 23 of Set 9 | lorengau
# Processing Record 24 of Set 9 | yulara
# Processing Record 25 of Set 9 | the valley
# Processing Record 26 of Set 9 | iaciara
# Processing Record 27 of Set 9 | seoul
# Processing Record 28 of Set 9 | shimoda
# Processing Record 29 of Set 9 | asayita
# City not found. Skipping...
# Processing Record 30 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 31 of Set 9 | cookeville
# Processing Record 32 of Set 9 | folkestone
# Processing Record 33 of Set 9 | basar
# Processing Record 34 of Set 9 | marsa matruh
# Processing Record 35 of Set 9 | ipixuna
# Processing Record 36 of Set 9 | faaborg
# Processing Record 37 of Set 9 | porlamar
# Processing Record 38 of Set 9 | caramoran
# Processing Record 39 of Set 9 | sao francisco
# Processing Record 40 of Set 9 | grand-santi
# Processing Record 41 of Set 9 | orsta
# Processing Record 42 of Set 9 | quelimane
# Processing Record 43 of Set 9 | macapa
# Processing Record 44 of Set 9 | martinsicuro
# Processing Record 45 of Set 9 | vraca
# Processing Record 46 of Set 9 | nouakchott
# Processing Record 47 of Set 9 | marabba
# Processing Record 48 of Set 9 | kracheh
# City not found. Skipping...
# Processing Record 49 of Set 9 | vila
# Processing Record 50 of Set 9 | sulangan
# Processing Record 1 of Set 10 | sierpc
# Processing Record 2 of Set 10 | klaksvik
# Processing Record 3 of Set 10 | buchanan
# Processing Record 4 of Set 10 | vostok
# Processing Record 5 of Set 10 | saint-augustin
# Processing Record 6 of Set 10 | torbay
# Processing Record 7 of Set 10 | namibe
# Processing Record 8 of Set 10 | red bank
# Processing Record 9 of Set 10 | beringovskiy
# Processing Record 10 of Set 10 | dakar
# Processing Record 11 of Set 10 | jibuti
# Processing Record 12 of Set 10 | iracoubo
# Processing Record 13 of Set 10 | nishihara
# Processing Record 14 of Set 10 | maues
# Processing Record 15 of Set 10 | novo aripuana
# Processing Record 16 of Set 10 | tigil
# Processing Record 17 of Set 10 | talnakh
# Processing Record 18 of Set 10 | bath
# Processing Record 19 of Set 10 | kieta
# Processing Record 20 of Set 10 | joaima
# Processing Record 21 of Set 10 | lahaina
# Processing Record 22 of Set 10 | gat
# Processing Record 23 of Set 10 | antofagasta
# Processing Record 24 of Set 10 | henties bay
# Processing Record 25 of Set 10 | cotonou
# Processing Record 26 of Set 10 | hlatikulu
# Processing Record 27 of Set 10 | dodola
# Processing Record 28 of Set 10 | aboso
# Processing Record 29 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 30 of Set 10 | bethanien
# Processing Record 31 of Set 10 | nelson bay
# Processing Record 32 of Set 10 | caranavi
# Processing Record 33 of Set 10 | oranjestad
# Processing Record 34 of Set 10 | yuxia
# Processing Record 35 of Set 10 | saint anthony
# Processing Record 36 of Set 10 | nanakuli
# Processing Record 37 of Set 10 | gallup
# Processing Record 38 of Set 10 | tokat
# Processing Record 39 of Set 10 | ayan
# Processing Record 40 of Set 10 | coquimbo
# Processing Record 41 of Set 10 | bure
# Processing Record 42 of Set 10 | arawa
# Processing Record 43 of Set 10 | sistranda
# Processing Record 44 of Set 10 | breves
# Processing Record 45 of Set 10 | roald
# Processing Record 46 of Set 10 | bialogard
# Processing Record 47 of Set 10 | santa rosalia
# Processing Record 48 of Set 10 | zeya
# Processing Record 49 of Set 10 | nome
# Processing Record 50 of Set 10 | khuzdar
# Processing Record 1 of Set 11 | laguna
# Processing Record 2 of Set 11 | bontang
# Processing Record 3 of Set 11 | havre-saint-pierre
# Processing Record 4 of Set 11 | naze
# Processing Record 5 of Set 11 | quimper
# Processing Record 6 of Set 11 | vestmanna
# Processing Record 7 of Set 11 | matara
# Processing Record 8 of Set 11 | gogrial
# Processing Record 9 of Set 11 | abu samrah
# Processing Record 10 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 11 of Set 11 | karratha
# Processing Record 12 of Set 11 | inuvik
# Processing Record 13 of Set 11 | columbus
# Processing Record 14 of Set 11 | cabo san lucas
# Processing Record 15 of Set 11 | okha
# Processing Record 16 of Set 11 | sainte-julienne
# Processing Record 17 of Set 11 | luganville
# Processing Record 18 of Set 11 | harper
# Processing Record 19 of Set 11 | lucapa
# Processing Record 20 of Set 11 | cajnice
# Processing Record 21 of Set 11 | ust-shonosha
# Processing Record 22 of Set 11 | trincomalee
# Processing Record 23 of Set 11 | aracaju
# Processing Record 24 of Set 11 | araouane
# Processing Record 25 of Set 11 | washington
# Processing Record 26 of Set 11 | san cosme y damian
# Processing Record 27 of Set 11 | placerville
# Processing Record 28 of Set 11 | ivanishchi
# Processing Record 29 of Set 11 | sobolevo
# Processing Record 30 of Set 11 | balykshi
# Processing Record 31 of Set 11 | kjollefjord
# Processing Record 32 of Set 11 | nuevo progreso
# Processing Record 33 of Set 11 | zhezkazgan
# Processing Record 34 of Set 11 | falesti
# Processing Record 35 of Set 11 | trelew
# Processing Record 36 of Set 11 | la ronge
# Processing Record 37 of Set 11 | hambantota
# Processing Record 38 of Set 11 | chesma
# Processing Record 39 of Set 11 | phalaborwa
# Processing Record 40 of Set 11 | taveta
# Processing Record 41 of Set 11 | nizhnevartovsk
# Processing Record 42 of Set 11 | dolores
# Processing Record 43 of Set 11 | teya
# Processing Record 44 of Set 11 | lazaro cardenas
# Processing Record 45 of Set 11 | tucuma
# Processing Record 46 of Set 11 | altoona
# Processing Record 47 of Set 11 | laibin
# Processing Record 48 of Set 11 | wulanhaote
# City not found. Skipping...
# Processing Record 49 of Set 11 | jardim
# Processing Record 50 of Set 11 | ngunguru
# Processing Record 1 of Set 12 | berezanka
# Processing Record 2 of Set 12 | bambanglipuro
# Processing Record 3 of Set 12 | cockburn town
# Processing Record 4 of Set 12 | kuytun
# Processing Record 5 of Set 12 | kirakira
# Processing Record 6 of Set 12 | mozarlandia
# Processing Record 7 of Set 12 | port hedland
# Processing Record 8 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 9 of Set 12 | bogorodskoye
# Processing Record 10 of Set 12 | braco do norte
# Processing Record 11 of Set 12 | gondanglegi
# Processing Record 12 of Set 12 | chom bung
# City not found. Skipping...
# Processing Record 13 of Set 12 | liverpool
# Processing Record 14 of Set 12 | severnoye
# Processing Record 15 of Set 12 | dasoguz
# Processing Record 16 of Set 12 | roma
# Processing Record 17 of Set 12 | ferkessedougou
# Processing Record 18 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 19 of Set 12 | ferrol
# Processing Record 20 of Set 12 | frederico westphalen
# Processing Record 21 of Set 12 | ouahigouya
# Processing Record 22 of Set 12 | kilmez
# City not found. Skipping...
# Processing Record 23 of Set 12 | nioro
# Processing Record 24 of Set 12 | miles city
# Processing Record 25 of Set 12 | romanovo
# Processing Record 26 of Set 12 | augusto correa
# Processing Record 27 of Set 12 | anadyr
# Processing Record 28 of Set 12 | jyvaskyla
# Processing Record 29 of Set 12 | puerto madryn
# Processing Record 30 of Set 12 | itigi
# Processing Record 31 of Set 12 | inyonga
# Processing Record 32 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 33 of Set 12 | juquitiba
# Processing Record 34 of Set 12 | ituni
# City not found. Skipping...
# Processing Record 35 of Set 12 | zhengjiatun
# Processing Record 36 of Set 12 | vientiane
# Processing Record 37 of Set 12 | saint-orens-de-gameville
# Processing Record 38 of Set 12 | komsomolskiy
# Processing Record 39 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 40 of Set 12 | svirsk
# Processing Record 41 of Set 12 | pelym
# Processing Record 42 of Set 12 | rafaela
# Processing Record 43 of Set 12 | manjacaze
# Processing Record 44 of Set 12 | vao
# Processing Record 45 of Set 12 | limon
# Processing Record 46 of Set 12 | krasnoselkup
# Processing Record 47 of Set 12 | cayenne
# Processing Record 48 of Set 12 | bukoba
# Processing Record 49 of Set 12 | vestmannaeyjar
# Processing Record 50 of Set 12 | taoudenni
# Processing Record 1 of Set 13 | uruburetama
# Processing Record 2 of Set 13 | santa cruz cabralia
# Processing Record 3 of Set 13 | correia pinto
# Processing Record 4 of Set 13 | polkowice
# Processing Record 5 of Set 13 | sabang
# Processing Record 6 of Set 13 | gilgit
# Processing Record 7 of Set 13 | hovd
# Processing Record 8 of Set 13 | nizhnyaya poyma
# Processing Record 9 of Set 13 | half moon bay
# Processing Record 10 of Set 13 | buenos aires
# Processing Record 11 of Set 13 | solnechnyy
# Processing Record 12 of Set 13 | meaford
# Processing Record 13 of Set 13 | santa rosa
# Processing Record 14 of Set 13 | sumbawa
# City not found. Skipping...
# Processing Record 15 of Set 13 | zhigansk
# Processing Record 16 of Set 13 | sakata
# Processing Record 17 of Set 13 | azrow
# City not found. Skipping...
# Processing Record 18 of Set 13 | economy
# Processing Record 19 of Set 13 | coos bay
# Processing Record 20 of Set 13 | barinas
# Processing Record 21 of Set 13 | woodway
# Processing Record 22 of Set 13 | santa teresa
# Processing Record 23 of Set 13 | sorland
# Processing Record 24 of Set 13 | kedrovyy
# Processing Record 25 of Set 13 | gigmoto
# Processing Record 26 of Set 13 | jumla
# Processing Record 27 of Set 13 | sidi qasim
# City not found. Skipping...
# Processing Record 28 of Set 13 | rincon
# Processing Record 29 of Set 13 | kachiry
# Processing Record 30 of Set 13 | suntar
# Processing Record 31 of Set 13 | atasu
# Processing Record 32 of Set 13 | mingaora
# Processing Record 33 of Set 13 | las palmas
# Processing Record 34 of Set 13 | herat
# Processing Record 35 of Set 13 | tehachapi
# Processing Record 36 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 37 of Set 13 | sotouboua
# Processing Record 38 of Set 13 | bakchar
# Processing Record 39 of Set 13 | nuevitas
# Processing Record 40 of Set 13 | graulhet
# Processing Record 41 of Set 13 | ambovombe
# Processing Record 42 of Set 13 | letlhakane
# Processing Record 43 of Set 13 | xianshuigu
# Processing Record 44 of Set 13 | skelleftea
# Processing Record 45 of Set 13 | ishigaki
# Processing Record 46 of Set 13 | pingzhuang
# Processing Record 47 of Set 13 | omboue
# Processing Record 48 of Set 13 | hobyo
# Processing Record 49 of Set 13 | maceio
# Processing Record 50 of Set 13 | sheltozero
# Processing Record 1 of Set 14 | kaeo
# Processing Record 2 of Set 14 | zharkent
# Processing Record 3 of Set 14 | morwa
# Processing Record 4 of Set 14 | sigli
# Processing Record 5 of Set 14 | ust-kulom
# Processing Record 6 of Set 14 | maraba
# Processing Record 7 of Set 14 | novyy urgal
# Processing Record 8 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 9 of Set 14 | labuan
# Processing Record 10 of Set 14 | parrita
# Processing Record 11 of Set 14 | skiros
# City not found. Skipping...
# Processing Record 12 of Set 14 | srandakan
# Processing Record 13 of Set 14 | barisal
# Processing Record 14 of Set 14 | mirador
# Processing Record 15 of Set 14 | blankenberge
# Processing Record 16 of Set 14 | urumqi
# Processing Record 17 of Set 14 | lujiang
# Processing Record 18 of Set 14 | afua
# Processing Record 19 of Set 14 | wattegama
# Processing Record 20 of Set 14 | kipushi
# Processing Record 21 of Set 14 | san isidro
# Processing Record 22 of Set 14 | guipavas
# Processing Record 23 of Set 14 | antalaha
# Processing Record 24 of Set 14 | lavrentiya
# Processing Record 25 of Set 14 | tura
# Processing Record 26 of Set 14 | san patricio
# Processing Record 27 of Set 14 | vitim
# Processing Record 28 of Set 14 | duz
# City not found. Skipping...
# Processing Record 29 of Set 14 | abiy adi
# City not found. Skipping...
# Processing Record 30 of Set 14 | sechura
# Processing Record 31 of Set 14 | poya
# Processing Record 32 of Set 14 | darhan
# Processing Record 33 of Set 14 | lykhivka
# Processing Record 34 of Set 14 | orlik
# Processing Record 35 of Set 14 | chapleau
# Processing Record 36 of Set 14 | olinda
# Processing Record 37 of Set 14 | saryg-sep
# Processing Record 38 of Set 14 | lanigan
# Processing Record 39 of Set 14 | pochutla
# Processing Record 40 of Set 14 | soubre
# Processing Record 41 of Set 14 | coahuayana
# Processing Record 42 of Set 14 | batagay
# Processing Record 43 of Set 14 | balad
# Processing Record 44 of Set 14 | mersin
# Processing Record 45 of Set 14 | ahuimanu
# Processing Record 46 of Set 14 | shelburne
# Processing Record 47 of Set 14 | khasan
# Processing Record 48 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 50 of Set 14 | macas
# Processing Record 1 of Set 15 | chunskiy
# Processing Record 2 of Set 15 | lashio
# Processing Record 3 of Set 15 | arrecife
# Processing Record 4 of Set 15 | plettenberg bay
# Processing Record 5 of Set 15 | kilindoni
# Processing Record 6 of Set 15 | ohafia
# Processing Record 7 of Set 15 | santiago
# Processing Record 8 of Set 15 | california city
# Processing Record 9 of Set 15 | catamarca
# Processing Record 10 of Set 15 | nogliki
# Processing Record 11 of Set 15 | aban
# Processing Record 12 of Set 15 | la primavera
# Processing Record 13 of Set 15 | faya
# Processing Record 14 of Set 15 | ayabaca
# Processing Record 15 of Set 15 | timra
# Processing Record 16 of Set 15 | wajima
# Processing Record 17 of Set 15 | shevchenko
# Processing Record 18 of Set 15 | belmonte
# Processing Record 19 of Set 15 | methven
# Processing Record 20 of Set 15 | marienburg
# Processing Record 21 of Set 15 | puerto del rosario
# Processing Record 22 of Set 15 | karpogory
# Processing Record 23 of Set 15 | amambai
# Processing Record 24 of Set 15 | tikrit
# Processing Record 25 of Set 15 | mbour
# Processing Record 26 of Set 15 | gatesville
# Processing Record 27 of Set 15 | camacupa
# Processing Record 28 of Set 15 | tessalit
# Processing Record 29 of Set 15 | hualmay
# Processing Record 30 of Set 15 | husavik
# Processing Record 31 of Set 15 | puerto narino
# Processing Record 32 of Set 15 | berlevag
# Processing Record 33 of Set 15 | wonthaggi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  East London      ZA -33.0153   27.9116     62.33        81          22
# 1     Thompson      CA  55.7435  -97.8558     33.96        93          90
# 2      Colares      PT  38.7992   -9.4469     68.99        85         100
# 3      Mataura      NZ -46.1927  168.8643     45.75        98         100
# 4      Ushuaia      AR -54.8000  -68.3000     46.06        53           0
# 5   Codrington      AU -38.2667  141.9667     62.37        55           0
# 6         Babu      CN  24.4167  111.5167     64.44        96         100
# 7       Touros      BR  -5.1989  -35.4608     77.90        76          96
# 8    Busselton      AU -33.6500  115.3333     66.04        63          97
# 9          Qom      IR  34.6401   50.8764     60.21        53          14
#
#    Wind Speed                  Description
# 0        4.99                   few clouds
# 1        6.91  light intensity shower rain
# 2        3.00              overcast clouds
# 3       12.71              overcast clouds
# 4       13.80                    clear sky
# 5        4.72                    clear sky
# 6        1.92              overcast clouds
# 7       14.85              overcast clouds
# 8        3.49              overcast clouds
# 9        2.08                   few clouds

# %%
#create the output file (csv)
output_data_file = "Weather_Database.cvs"
#export the city_data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
