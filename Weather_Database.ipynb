# %%
#import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from citipy import citipy
import requests
from datetime import datetime 
from config import weather_api_key

# %%
#create a new set of random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
coordinates = zip(lats,lngs)
coordinates

# %%
#add the coordinates to a list
coordinates = list(coordinates)

# %%
#get the nearest city using the citipy module
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 741

# %%
#perform an API call with the OpenWeatherMap
city_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#retrieve information from the API call.

#create an empty list to hold the weather data
city_data = []
#print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
#create counters.
record_count = 1
set_count = 1

#loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city.
    url = city_url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_wdesc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_wdesc})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | katiola
# Processing Record 2 of Set 1 | hamilton
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | saint-philippe
# Processing Record 8 of Set 1 | atuona
# Processing Record 9 of Set 1 | mar del plata
# Processing Record 10 of Set 1 | namatanai
# Processing Record 11 of Set 1 | rosarito
# Processing Record 12 of Set 1 | hilo
# Processing Record 13 of Set 1 | morondava
# Processing Record 14 of Set 1 | faanui
# Processing Record 15 of Set 1 | panjab
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | bonavista
# Processing Record 18 of Set 1 | sitka
# Processing Record 19 of Set 1 | lebu
# Processing Record 20 of Set 1 | bemidji
# Processing Record 21 of Set 1 | chara
# Processing Record 22 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 1 | severo-kurilsk
# Processing Record 24 of Set 1 | sorland
# Processing Record 25 of Set 1 | gizo
# Processing Record 26 of Set 1 | vaini
# Processing Record 27 of Set 1 | pochutla
# Processing Record 28 of Set 1 | southbridge
# Processing Record 29 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 30 of Set 1 | porto santo
# Processing Record 31 of Set 1 | baker city
# Processing Record 32 of Set 1 | port elizabeth
# Processing Record 33 of Set 1 | albany
# Processing Record 34 of Set 1 | wahran
# City not found. Skipping...
# Processing Record 35 of Set 1 | leningradskiy
# Processing Record 36 of Set 1 | andenes
# Processing Record 37 of Set 1 | pilar
# Processing Record 38 of Set 1 | solnechnyy
# Processing Record 39 of Set 1 | dudinka
# Processing Record 40 of Set 1 | mataura
# Processing Record 41 of Set 1 | turmalina
# Processing Record 42 of Set 1 | butaritari
# Processing Record 43 of Set 1 | upata
# Processing Record 44 of Set 1 | bluff
# Processing Record 45 of Set 1 | mount gambier
# Processing Record 46 of Set 1 | guarapari
# Processing Record 47 of Set 1 | leirvik
# Processing Record 48 of Set 1 | nanortalik
# Processing Record 49 of Set 1 | coihueco
# Processing Record 50 of Set 1 | bredasdorp
# Processing Record 1 of Set 2 | cherskiy
# Processing Record 2 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 3 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 2 | qasigiannguit
# Processing Record 5 of Set 2 | east london
# Processing Record 6 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 2 | aklavik
# Processing Record 8 of Set 2 | abu jubayhah
# City not found. Skipping...
# Processing Record 9 of Set 2 | kapaa
# Processing Record 10 of Set 2 | mamallapuram
# Processing Record 11 of Set 2 | bathsheba
# Processing Record 12 of Set 2 | los llanos de aridane
# Processing Record 13 of Set 2 | killybegs
# Processing Record 14 of Set 2 | laguna
# Processing Record 15 of Set 2 | qaanaaq
# Processing Record 16 of Set 2 | acajutla
# Processing Record 17 of Set 2 | tunxi
# City not found. Skipping...
# Processing Record 18 of Set 2 | havre-saint-pierre
# Processing Record 19 of Set 2 | manadhoo
# Processing Record 20 of Set 2 | chuy
# Processing Record 21 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 2 | qinhuangdao
# Processing Record 23 of Set 2 | bambous virieux
# Processing Record 24 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 25 of Set 2 | atasu
# Processing Record 26 of Set 2 | castro
# Processing Record 27 of Set 2 | zhigalovo
# Processing Record 28 of Set 2 | kangaatsiaq
# Processing Record 29 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 2 | fort payne
# Processing Record 31 of Set 2 | bac lieu
# Processing Record 32 of Set 2 | yellowknife
# Processing Record 33 of Set 2 | poum
# Processing Record 34 of Set 2 | newport
# Processing Record 35 of Set 2 | sorso
# Processing Record 36 of Set 2 | jamestown
# Processing Record 37 of Set 2 | san andres
# Processing Record 38 of Set 2 | iqaluit
# Processing Record 39 of Set 2 | georgetown
# Processing Record 40 of Set 2 | vila velha
# Processing Record 41 of Set 2 | salinopolis
# Processing Record 42 of Set 2 | khabary
# Processing Record 43 of Set 2 | ponta do sol
# Processing Record 44 of Set 2 | tyrma
# Processing Record 45 of Set 2 | dingle
# Processing Record 46 of Set 2 | katsuura
# Processing Record 47 of Set 2 | palmer
# Processing Record 48 of Set 2 | praya
# Processing Record 49 of Set 2 | tuktoyaktuk
# Processing Record 50 of Set 2 | bartica
# Processing Record 1 of Set 3 | arraial do cabo
# Processing Record 2 of Set 3 | peoria
# Processing Record 3 of Set 3 | tessalit
# Processing Record 4 of Set 3 | formosa
# Processing Record 5 of Set 3 | pevek
# Processing Record 6 of Set 3 | hobart
# Processing Record 7 of Set 3 | woodstock
# Processing Record 8 of Set 3 | haibowan
# City not found. Skipping...
# Processing Record 9 of Set 3 | nelson bay
# Processing Record 10 of Set 3 | nikolskoye
# Processing Record 11 of Set 3 | cootamundra
# Processing Record 12 of Set 3 | cape town
# Processing Record 13 of Set 3 | teodoro sampaio
# Processing Record 14 of Set 3 | buraydah
# Processing Record 15 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 16 of Set 3 | korla
# Processing Record 17 of Set 3 | rabat
# Processing Record 18 of Set 3 | liwale
# Processing Record 19 of Set 3 | shillong
# Processing Record 20 of Set 3 | ayan
# Processing Record 21 of Set 3 | carnarvon
# Processing Record 22 of Set 3 | bethel
# Processing Record 23 of Set 3 | washington
# Processing Record 24 of Set 3 | puerto ayora
# Processing Record 25 of Set 3 | avarua
# Processing Record 26 of Set 3 | aksu
# Processing Record 27 of Set 3 | mixtepec
# City not found. Skipping...
# Processing Record 28 of Set 3 | menongue
# Processing Record 29 of Set 3 | jaru
# Processing Record 30 of Set 3 | mumford
# Processing Record 31 of Set 3 | nenjiang
# Processing Record 32 of Set 3 | drayton valley
# Processing Record 33 of Set 3 | carutapera
# Processing Record 34 of Set 3 | new norfolk
# Processing Record 35 of Set 3 | cayenne
# Processing Record 36 of Set 3 | cidreira
# Processing Record 37 of Set 3 | norfolk
# Processing Record 38 of Set 3 | yulara
# Processing Record 39 of Set 3 | usevya
# Processing Record 40 of Set 3 | ahuimanu
# Processing Record 41 of Set 3 | namibe
# Processing Record 42 of Set 3 | chokurdakh
# Processing Record 43 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 3 | weihe
# Processing Record 45 of Set 3 | ankazobe
# Processing Record 46 of Set 3 | ondjiva
# Processing Record 47 of Set 3 | tuatapere
# Processing Record 48 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 3 | lompoc
# Processing Record 50 of Set 3 | naryan-mar
# Processing Record 1 of Set 4 | lincoln
# Processing Record 2 of Set 4 | san cristobal
# Processing Record 3 of Set 4 | umm lajj
# Processing Record 4 of Set 4 | anamur
# Processing Record 5 of Set 4 | ziarat
# Processing Record 6 of Set 4 | shenjiamen
# Processing Record 7 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 4 | sao jose da coroa grande
# Processing Record 9 of Set 4 | galiwinku
# City not found. Skipping...
# Processing Record 10 of Set 4 | saldanha
# Processing Record 11 of Set 4 | torbay
# Processing Record 12 of Set 4 | cuamba
# Processing Record 13 of Set 4 | nishihara
# Processing Record 14 of Set 4 | hermanus
# Processing Record 15 of Set 4 | urucara
# Processing Record 16 of Set 4 | airai
# Processing Record 17 of Set 4 | ribeira grande
# Processing Record 18 of Set 4 | goderich
# Processing Record 19 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 20 of Set 4 | coro
# Processing Record 21 of Set 4 | lusambo
# Processing Record 22 of Set 4 | olinda
# Processing Record 23 of Set 4 | hofn
# Processing Record 24 of Set 4 | ancud
# Processing Record 25 of Set 4 | kandrian
# Processing Record 26 of Set 4 | poplar bluff
# Processing Record 27 of Set 4 | ornskoldsvik
# Processing Record 28 of Set 4 | navahrudak
# Processing Record 29 of Set 4 | dikson
# Processing Record 30 of Set 4 | jumla
# Processing Record 31 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 4 | sept-iles
# Processing Record 33 of Set 4 | pangnirtung
# Processing Record 34 of Set 4 | kodiak
# Processing Record 35 of Set 4 | sao joao da barra
# Processing Record 36 of Set 4 | gijon
# Processing Record 37 of Set 4 | tasiilaq
# Processing Record 38 of Set 4 | pangody
# Processing Record 39 of Set 4 | lander
# Processing Record 40 of Set 4 | hasaki
# Processing Record 41 of Set 4 | kaitangata
# Processing Record 42 of Set 4 | hobyo
# Processing Record 43 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 4 | mount isa
# Processing Record 45 of Set 4 | kostomuksha
# Processing Record 46 of Set 4 | bosaso
# Processing Record 47 of Set 4 | eyl
# Processing Record 48 of Set 4 | labuhan
# Processing Record 49 of Set 4 | port blair
# Processing Record 50 of Set 4 | milkovo
# Processing Record 1 of Set 5 | guerrero negro
# Processing Record 2 of Set 5 | kitimat
# Processing Record 3 of Set 5 | deputatskiy
# Processing Record 4 of Set 5 | neryungri
# Processing Record 5 of Set 5 | suez
# Processing Record 6 of Set 5 | neiafu
# Processing Record 7 of Set 5 | kutum
# Processing Record 8 of Set 5 | port alfred
# Processing Record 9 of Set 5 | algiers
# Processing Record 10 of Set 5 | thinadhoo
# Processing Record 11 of Set 5 | richards bay
# Processing Record 12 of Set 5 | vostok
# Processing Record 13 of Set 5 | kavaratti
# Processing Record 14 of Set 5 | dolbeau
# City not found. Skipping...
# Processing Record 15 of Set 5 | barrow
# Processing Record 16 of Set 5 | muros
# Processing Record 17 of Set 5 | tomatlan
# Processing Record 18 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 19 of Set 5 | saint-pierre
# Processing Record 20 of Set 5 | ivanovka
# Processing Record 21 of Set 5 | angoche
# Processing Record 22 of Set 5 | fortuna
# Processing Record 23 of Set 5 | antakya
# Processing Record 24 of Set 5 | denpasar
# Processing Record 25 of Set 5 | macae
# Processing Record 26 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 5 | merauke
# Processing Record 28 of Set 5 | codrington
# Processing Record 29 of Set 5 | bilma
# Processing Record 30 of Set 5 | matelandia
# Processing Record 31 of Set 5 | cockburn town
# Processing Record 32 of Set 5 | baraboo
# Processing Record 33 of Set 5 | khatanga
# Processing Record 34 of Set 5 | huilong
# Processing Record 35 of Set 5 | catuday
# Processing Record 36 of Set 5 | khuzhir
# Processing Record 37 of Set 5 | bubaque
# Processing Record 38 of Set 5 | byron bay
# Processing Record 39 of Set 5 | thompson
# Processing Record 40 of Set 5 | tyukhtet
# Processing Record 41 of Set 5 | souillac
# Processing Record 42 of Set 5 | praia da vitoria
# Processing Record 43 of Set 5 | akdepe
# Processing Record 44 of Set 5 | safwah
# City not found. Skipping...
# Processing Record 45 of Set 5 | basoko
# Processing Record 46 of Set 5 | sirjan
# Processing Record 47 of Set 5 | longyearbyen
# Processing Record 48 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 49 of Set 5 | muravlenko
# Processing Record 50 of Set 5 | inuvik
# Processing Record 1 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 2 of Set 6 | riyadh
# Processing Record 3 of Set 6 | san jeronimo
# Processing Record 4 of Set 6 | cortes
# Processing Record 5 of Set 6 | weyburn
# Processing Record 6 of Set 6 | honiara
# Processing Record 7 of Set 6 | constitucion
# Processing Record 8 of Set 6 | bucerias
# Processing Record 9 of Set 6 | zhezkazgan
# Processing Record 10 of Set 6 | fort nelson
# Processing Record 11 of Set 6 | meulaboh
# Processing Record 12 of Set 6 | rio cuarto
# Processing Record 13 of Set 6 | wadi musa
# Processing Record 14 of Set 6 | linfen
# Processing Record 15 of Set 6 | uchiza
# Processing Record 16 of Set 6 | lazaro cardenas
# Processing Record 17 of Set 6 | iranshahr
# Processing Record 18 of Set 6 | sao filipe
# Processing Record 19 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 6 | coihaique
# Processing Record 21 of Set 6 | orlik
# Processing Record 22 of Set 6 | esperance
# Processing Record 23 of Set 6 | ukiah
# Processing Record 24 of Set 6 | danville
# Processing Record 25 of Set 6 | maniitsoq
# Processing Record 26 of Set 6 | urumqi
# Processing Record 27 of Set 6 | norman wells
# Processing Record 28 of Set 6 | balgazyn
# Processing Record 29 of Set 6 | svetlaya
# Processing Record 30 of Set 6 | lavrentiya
# Processing Record 31 of Set 6 | ostrovnoy
# Processing Record 32 of Set 6 | smithers
# Processing Record 33 of Set 6 | abakan
# Processing Record 34 of Set 6 | victoria
# Processing Record 35 of Set 6 | leua
# Processing Record 36 of Set 6 | pindiga
# Processing Record 37 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 38 of Set 6 | mitsamiouli
# Processing Record 39 of Set 6 | pimentel
# Processing Record 40 of Set 6 | atherton
# Processing Record 41 of Set 6 | mahebourg
# Processing Record 42 of Set 6 | tamandare
# Processing Record 43 of Set 6 | galgani
# City not found. Skipping...
# Processing Record 44 of Set 6 | tocopilla
# Processing Record 45 of Set 6 | tirat karmel
# Processing Record 46 of Set 6 | strezhevoy
# Processing Record 47 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 48 of Set 6 | clyde river
# Processing Record 49 of Set 6 | naze
# Processing Record 50 of Set 6 | kirakira
# Processing Record 1 of Set 7 | silale
# Processing Record 2 of Set 7 | geraldton
# Processing Record 3 of Set 7 | guilin
# Processing Record 4 of Set 7 | katha
# City not found. Skipping...
# Processing Record 5 of Set 7 | belaya gora
# Processing Record 6 of Set 7 | gat
# Processing Record 7 of Set 7 | saint george
# Processing Record 8 of Set 7 | samarai
# Processing Record 9 of Set 7 | haimen
# Processing Record 10 of Set 7 | nawa
# Processing Record 11 of Set 7 | edremit
# Processing Record 12 of Set 7 | makakilo city
# Processing Record 13 of Set 7 | touros
# Processing Record 14 of Set 7 | daru
# Processing Record 15 of Set 7 | port macquarie
# Processing Record 16 of Set 7 | hetauda
# Processing Record 17 of Set 7 | mangai
# Processing Record 18 of Set 7 | tukrah
# Processing Record 19 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 7 | coquimbo
# Processing Record 21 of Set 7 | banjarmasin
# Processing Record 22 of Set 7 | shimoda
# Processing Record 23 of Set 7 | slavyanka
# Processing Record 24 of Set 7 | dongli
# Processing Record 25 of Set 7 | old road
# City not found. Skipping...
# Processing Record 26 of Set 7 | kedougou
# Processing Record 27 of Set 7 | vathilakkos
# City not found. Skipping...
# Processing Record 28 of Set 7 | kamaishi
# Processing Record 29 of Set 7 | borba
# Processing Record 30 of Set 7 | ardakan
# Processing Record 31 of Set 7 | misratah
# Processing Record 32 of Set 7 | yar-sale
# Processing Record 33 of Set 7 | roald
# Processing Record 34 of Set 7 | sahrak
# City not found. Skipping...
# Processing Record 35 of Set 7 | narsaq
# Processing Record 36 of Set 7 | upernavik
# Processing Record 37 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 7 | ilulissat
# Processing Record 39 of Set 7 | ishigaki
# Processing Record 40 of Set 7 | okha
# Processing Record 41 of Set 7 | kloulklubed
# Processing Record 42 of Set 7 | port lincoln
# Processing Record 43 of Set 7 | tunduru
# City not found. Skipping...
# Processing Record 44 of Set 7 | kailua
# Processing Record 45 of Set 7 | haines junction
# Processing Record 46 of Set 7 | launceston
# Processing Record 47 of Set 7 | pierre
# Processing Record 48 of Set 7 | hervey bay
# Processing Record 49 of Set 7 | paamiut
# Processing Record 50 of Set 7 | luwuk
# Processing Record 1 of Set 8 | mansa
# Processing Record 2 of Set 8 | oga
# Processing Record 3 of Set 8 | ixtapa
# Processing Record 4 of Set 8 | talcahuano
# Processing Record 5 of Set 8 | esmeraldas
# Processing Record 6 of Set 8 | jujuy
# City not found. Skipping...
# Processing Record 7 of Set 8 | hithadhoo
# Processing Record 8 of Set 8 | saskylakh
# Processing Record 9 of Set 8 | klaksvik
# Processing Record 10 of Set 8 | tabas
# Processing Record 11 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 8 | kavieng
# Processing Record 13 of Set 8 | sompeta
# Processing Record 14 of Set 8 | san patricio
# Processing Record 15 of Set 8 | barra patuca
# Processing Record 16 of Set 8 | labuan
# Processing Record 17 of Set 8 | makung
# City not found. Skipping...
# Processing Record 18 of Set 8 | porto novo
# Processing Record 19 of Set 8 | mao
# Processing Record 20 of Set 8 | biak
# Processing Record 21 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 22 of Set 8 | garissa
# Processing Record 23 of Set 8 | saint anthony
# Processing Record 24 of Set 8 | lianzhou
# Processing Record 25 of Set 8 | yatou
# Processing Record 26 of Set 8 | lagoa
# Processing Record 27 of Set 8 | ondangwa
# Processing Record 28 of Set 8 | bandrele
# Processing Record 29 of Set 8 | mikhaylov
# Processing Record 30 of Set 8 | kahului
# Processing Record 31 of Set 8 | north bend
# Processing Record 32 of Set 8 | acapulco
# Processing Record 33 of Set 8 | young
# Processing Record 34 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 35 of Set 8 | bengkulu
# Processing Record 36 of Set 8 | tiksi
# Processing Record 37 of Set 8 | xining
# Processing Record 38 of Set 8 | williston
# Processing Record 39 of Set 8 | novoagansk
# Processing Record 40 of Set 8 | pittsburg
# Processing Record 41 of Set 8 | jalu
# Processing Record 42 of Set 8 | san luis
# Processing Record 43 of Set 8 | sobradinho
# Processing Record 44 of Set 8 | shahrud
# Processing Record 45 of Set 8 | whitehorse
# Processing Record 46 of Set 8 | sivaki
# Processing Record 47 of Set 8 | vestmannaeyjar
# Processing Record 48 of Set 8 | suntar
# Processing Record 49 of Set 8 | udachnyy
# Processing Record 50 of Set 8 | ampanihy
# Processing Record 1 of Set 9 | effingham
# Processing Record 2 of Set 9 | grindavik
# Processing Record 3 of Set 9 | coffs harbour
# Processing Record 4 of Set 9 | gornyy
# Processing Record 5 of Set 9 | balkhash
# Processing Record 6 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 9 | egvekinot
# Processing Record 8 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 9 of Set 9 | gzhatsk
# City not found. Skipping...
# Processing Record 10 of Set 9 | tezu
# Processing Record 11 of Set 9 | serenje
# Processing Record 12 of Set 9 | ulladulla
# Processing Record 13 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 14 of Set 9 | kerewan
# Processing Record 15 of Set 9 | oktyabrskoye
# Processing Record 16 of Set 9 | broken hill
# Processing Record 17 of Set 9 | jagannathpur
# Processing Record 18 of Set 9 | kapit
# Processing Record 19 of Set 9 | vila franca do campo
# Processing Record 20 of Set 9 | korhogo
# Processing Record 21 of Set 9 | jacqueville
# Processing Record 22 of Set 9 | sicuani
# Processing Record 23 of Set 9 | piacabucu
# Processing Record 24 of Set 9 | desnogorsk
# Processing Record 25 of Set 9 | presque isle
# Processing Record 26 of Set 9 | omboue
# Processing Record 27 of Set 9 | amga
# Processing Record 28 of Set 9 | lokosovo
# Processing Record 29 of Set 9 | nabire
# Processing Record 30 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 9 | debre zeyit
# Processing Record 32 of Set 9 | sanghar
# Processing Record 33 of Set 9 | manta
# Processing Record 34 of Set 9 | burns lake
# Processing Record 35 of Set 9 | kruisfontein
# Processing Record 36 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 37 of Set 9 | ulundi
# Processing Record 38 of Set 9 | karpathos
# Processing Record 39 of Set 9 | allonnes
# Processing Record 40 of Set 9 | solovetskiy
# City not found. Skipping...
# Processing Record 41 of Set 9 | natal
# Processing Record 42 of Set 9 | lorengau
# Processing Record 43 of Set 9 | bairiki
# Processing Record 44 of Set 9 | ottumwa
# Processing Record 45 of Set 9 | san policarpo
# Processing Record 46 of Set 9 | bonfim
# Processing Record 47 of Set 9 | hakodate
# Processing Record 48 of Set 9 | half moon bay
# Processing Record 49 of Set 9 | asfi
# Processing Record 50 of Set 9 | basco
# Processing Record 1 of Set 10 | troitskoye
# Processing Record 2 of Set 10 | jinchang
# Processing Record 3 of Set 10 | huarmey
# Processing Record 4 of Set 10 | eureka
# Processing Record 5 of Set 10 | chany
# Processing Record 6 of Set 10 | rawson
# Processing Record 7 of Set 10 | santa cruz
# Processing Record 8 of Set 10 | port hardy
# Processing Record 9 of Set 10 | kitob
# Processing Record 10 of Set 10 | cherdyn
# Processing Record 11 of Set 10 | yining
# Processing Record 12 of Set 10 | puerto leguizamo
# Processing Record 13 of Set 10 | jiangyou
# Processing Record 14 of Set 10 | kinkala
# Processing Record 15 of Set 10 | vangaindrano
# Processing Record 16 of Set 10 | shingu
# Processing Record 17 of Set 10 | lilongwe
# Processing Record 18 of Set 10 | valparaiso
# Processing Record 19 of Set 10 | buchanan
# Processing Record 20 of Set 10 | tura
# Processing Record 21 of Set 10 | jamame
# Processing Record 22 of Set 10 | alofi
# Processing Record 23 of Set 10 | bandarbeyla
# Processing Record 24 of Set 10 | santa cruz de tenerife
# Processing Record 25 of Set 10 | ardatov
# Processing Record 26 of Set 10 | nizhniy chir
# Processing Record 27 of Set 10 | plettenberg bay
# Processing Record 28 of Set 10 | karratha
# Processing Record 29 of Set 10 | kuzovatovo
# Processing Record 30 of Set 10 | rio gallegos
# Processing Record 31 of Set 10 | aras
# Processing Record 32 of Set 10 | altenstadt
# Processing Record 33 of Set 10 | marawi
# Processing Record 34 of Set 10 | divnogorsk
# Processing Record 35 of Set 10 | barentu
# Processing Record 36 of Set 10 | raudeberg
# Processing Record 37 of Set 10 | obihiro
# Processing Record 38 of Set 10 | luanda
# Processing Record 39 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 40 of Set 10 | liuzhou
# Processing Record 41 of Set 10 | wanning
# Processing Record 42 of Set 10 | aykhal
# Processing Record 43 of Set 10 | pucallpa
# Processing Record 44 of Set 10 | maceio
# Processing Record 45 of Set 10 | ust-tsilma
# Processing Record 46 of Set 10 | opuwo
# Processing Record 47 of Set 10 | alice springs
# Processing Record 48 of Set 10 | altamira
# Processing Record 49 of Set 10 | ridgecrest
# Processing Record 50 of Set 10 | plouzane
# Processing Record 1 of Set 11 | umea
# Processing Record 2 of Set 11 | caohe
# Processing Record 3 of Set 11 | nekhayevskiy
# Processing Record 4 of Set 11 | portland
# Processing Record 5 of Set 11 | seoul
# Processing Record 6 of Set 11 | douentza
# Processing Record 7 of Set 11 | preobrazheniye
# Processing Record 8 of Set 11 | inongo
# Processing Record 9 of Set 11 | bom jesus da lapa
# Processing Record 10 of Set 11 | havoysund
# Processing Record 11 of Set 11 | roebourne
# Processing Record 12 of Set 11 | lalomanu
# City not found. Skipping...
# Processing Record 13 of Set 11 | bandar penggaram
# City not found. Skipping...
# Processing Record 14 of Set 11 | taoudenni
# Processing Record 15 of Set 11 | bonthe
# Processing Record 16 of Set 11 | mogadishu
# Processing Record 17 of Set 11 | asau
# Processing Record 18 of Set 11 | arcos
# Processing Record 19 of Set 11 | severo-yeniseyskiy
# Processing Record 20 of Set 11 | gombong
# Processing Record 21 of Set 11 | mehamn
# Processing Record 22 of Set 11 | manicore
# Processing Record 23 of Set 11 | dunedin
# Processing Record 24 of Set 11 | sumenep
# Processing Record 25 of Set 11 | provideniya
# Processing Record 26 of Set 11 | bathurst
# Processing Record 27 of Set 11 | djang
# City not found. Skipping...
# Processing Record 28 of Set 11 | ketchikan
# Processing Record 29 of Set 11 | elk city
# Processing Record 30 of Set 11 | santa isabel do rio negro
# Processing Record 31 of Set 11 | berezovyy
# Processing Record 32 of Set 11 | tucuman
# Processing Record 33 of Set 11 | davenda
# Processing Record 34 of Set 11 | irtyshskiy
# Processing Record 35 of Set 11 | talnakh
# Processing Record 36 of Set 11 | bilibino
# Processing Record 37 of Set 11 | neverkino
# Processing Record 38 of Set 11 | vardo
# Processing Record 39 of Set 11 | hanna
# Processing Record 40 of Set 11 | pelym
# Processing Record 41 of Set 11 | itacare
# Processing Record 42 of Set 11 | pangkalanbuun
# Processing Record 43 of Set 11 | jibuti
# Processing Record 44 of Set 11 | mindelo
# Processing Record 45 of Set 11 | imbituba
# Processing Record 46 of Set 11 | mityana
# Processing Record 47 of Set 11 | seminole
# Processing Record 48 of Set 11 | guiyang
# Processing Record 49 of Set 11 | brae
# Processing Record 50 of Set 11 | gallup
# Processing Record 1 of Set 12 | suzun
# Processing Record 2 of Set 12 | lasa
# Processing Record 3 of Set 12 | beira
# Processing Record 4 of Set 12 | suileng
# Processing Record 5 of Set 12 | pacific grove
# Processing Record 6 of Set 12 | dharchula
# Processing Record 7 of Set 12 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 8 of Set 12 | nyurba
# Processing Record 9 of Set 12 | coahuayana
# Processing Record 10 of Set 12 | cockburn harbour
# City not found. Skipping...
# Processing Record 11 of Set 12 | aloleng
# Processing Record 12 of Set 12 | semirom
# Processing Record 13 of Set 12 | virginia beach
# Processing Record 14 of Set 12 | puerto escondido
# Processing Record 15 of Set 12 | beringovskiy
# Processing Record 16 of Set 12 | zhangye
# Processing Record 17 of Set 12 | palembang
# Processing Record 18 of Set 12 | khasan
# Processing Record 19 of Set 12 | vanimo
# Processing Record 20 of Set 12 | khandyga
# Processing Record 21 of Set 12 | zyryanka
# Processing Record 22 of Set 12 | partsa
# Processing Record 23 of Set 12 | vagur
# Processing Record 24 of Set 12 | ensenada
# Processing Record 25 of Set 12 | balabac
# Processing Record 26 of Set 12 | sola
# Processing Record 27 of Set 12 | sojat
# Processing Record 28 of Set 12 | vokhma
# Processing Record 29 of Set 12 | aconibe
# Processing Record 30 of Set 12 | senges
# Processing Record 31 of Set 12 | devils lake
# Processing Record 32 of Set 12 | galapagar
# Processing Record 33 of Set 12 | mercedes
# Processing Record 34 of Set 12 | ust-kuyga
# Processing Record 35 of Set 12 | port augusta
# Processing Record 36 of Set 12 | buala
# Processing Record 37 of Set 12 | bousso
# Processing Record 38 of Set 12 | saint-augustin
# Processing Record 39 of Set 12 | fairbanks
# Processing Record 40 of Set 12 | oriximina
# Processing Record 41 of Set 12 | polson
# Processing Record 42 of Set 12 | port-cartier
# Processing Record 43 of Set 12 | bongouanou
# Processing Record 44 of Set 12 | afmadu
# City not found. Skipping...
# Processing Record 45 of Set 12 | ibra
# Processing Record 46 of Set 12 | houma
# Processing Record 47 of Set 12 | leninskoye
# Processing Record 48 of Set 12 | gladstone
# Processing Record 49 of Set 12 | padron
# Processing Record 50 of Set 12 | pahalgam
# Processing Record 1 of Set 13 | linden
# Processing Record 2 of Set 13 | blaine
# Processing Record 3 of Set 13 | zima
# Processing Record 4 of Set 13 | adrar
# Processing Record 5 of Set 13 | vargashi
# Processing Record 6 of Set 13 | terme
# Processing Record 7 of Set 13 | talakan
# Processing Record 8 of Set 13 | aljezur
# Processing Record 9 of Set 13 | hualmay
# Processing Record 10 of Set 13 | rantepao
# Processing Record 11 of Set 13 | eskasem
# City not found. Skipping...
# Processing Record 12 of Set 13 | port victoria
# Processing Record 13 of Set 13 | monrovia
# Processing Record 14 of Set 13 | tripoli
# Processing Record 15 of Set 13 | kyra
# Processing Record 16 of Set 13 | nanchang
# Processing Record 17 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 13 | hambantota
# Processing Record 19 of Set 13 | warrington
# Processing Record 20 of Set 13 | flinders
# Processing Record 21 of Set 13 | tuggurt
# City not found. Skipping...
# Processing Record 22 of Set 13 | ouadda
# Processing Record 23 of Set 13 | kambove
# Processing Record 24 of Set 13 | saint-georges
# Processing Record 25 of Set 13 | mwinilunga
# Processing Record 26 of Set 13 | florianopolis
# Processing Record 27 of Set 13 | encantado
# Processing Record 28 of Set 13 | moramanga
# Processing Record 29 of Set 13 | thunder bay
# Processing Record 30 of Set 13 | vila
# Processing Record 31 of Set 13 | san juan
# Processing Record 32 of Set 13 | tubruq
# City not found. Skipping...
# Processing Record 33 of Set 13 | victoria point
# Processing Record 34 of Set 13 | khawhai
# Processing Record 35 of Set 13 | sibolga
# Processing Record 36 of Set 13 | camacha
# Processing Record 37 of Set 13 | mataram
# Processing Record 38 of Set 13 | el angel
# Processing Record 39 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 40 of Set 13 | bullingen
# City not found. Skipping...
# Processing Record 41 of Set 13 | quatre cocos
# Processing Record 42 of Set 13 | sabang
# Processing Record 43 of Set 13 | te anau
# Processing Record 44 of Set 13 | djibo
# Processing Record 45 of Set 13 | isla mujeres
# Processing Record 46 of Set 13 | rocha
# Processing Record 47 of Set 13 | caravelas
# Processing Record 48 of Set 13 | arrecife
# Processing Record 49 of Set 13 | visby
# Processing Record 50 of Set 13 | kupang
# Processing Record 1 of Set 14 | cabo san lucas
# Processing Record 2 of Set 14 | xinzhi
# Processing Record 3 of Set 14 | grand gaube
# Processing Record 4 of Set 14 | sulangan
# Processing Record 5 of Set 14 | kharp
# Processing Record 6 of Set 14 | pomoryany
# Processing Record 7 of Set 14 | mashhad
# Processing Record 8 of Set 14 | shu
# Processing Record 9 of Set 14 | kokkola
# Processing Record 10 of Set 14 | comodoro rivadavia
# Processing Record 11 of Set 14 | ambilobe
# Processing Record 12 of Set 14 | solsvik
# City not found. Skipping...
# Processing Record 13 of Set 14 | bone
# Processing Record 14 of Set 14 | lata
# Processing Record 15 of Set 14 | cairns
# Processing Record 16 of Set 14 | lake havasu city
# Processing Record 17 of Set 14 | muzhi
# Processing Record 18 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 19 of Set 14 | bolu
# Processing Record 20 of Set 14 | terryville
# Processing Record 21 of Set 14 | port-gentil
# Processing Record 22 of Set 14 | vanavara
# Processing Record 23 of Set 14 | bukene
# Processing Record 24 of Set 14 | kaihua
# Processing Record 25 of Set 14 | miri
# Processing Record 26 of Set 14 | sonoita
# Processing Record 27 of Set 14 | george
# Processing Record 28 of Set 14 | lugovskiy
# City not found. Skipping...
# Processing Record 29 of Set 14 | celestun
# Processing Record 30 of Set 14 | assiniboia
# Processing Record 31 of Set 14 | inirida
# Processing Record 32 of Set 14 | hoquiam
# Processing Record 33 of Set 14 | ucluelet
# Processing Record 34 of Set 14 | szeghalom
# Processing Record 35 of Set 14 | nome
# Processing Record 36 of Set 14 | kendari
# Processing Record 37 of Set 14 | xiongshi
# City not found. Skipping...
# Processing Record 38 of Set 14 | puerto penasco
# Processing Record 39 of Set 14 | muhos
# Processing Record 40 of Set 14 | ambodifototra
# City not found. Skipping...
# Processing Record 41 of Set 14 | belmonte
# Processing Record 42 of Set 14 | lazo
# Processing Record 43 of Set 14 | kirksville
# Processing Record 44 of Set 14 | santa engracia
# Processing Record 45 of Set 14 | sabla
# Processing Record 46 of Set 14 | rio pardo
# Processing Record 47 of Set 14 | yuanping
# Processing Record 48 of Set 14 | eenhana
# Processing Record 49 of Set 14 | raga
# Processing Record 50 of Set 14 | ternate
# Processing Record 1 of Set 15 | itarema
# Processing Record 2 of Set 15 | san quintin
# Processing Record 3 of Set 15 | pecangakan
# Processing Record 4 of Set 15 | elko
# Processing Record 5 of Set 15 | nizwa
# Processing Record 6 of Set 15 | dongsheng
# Processing Record 7 of Set 15 | pisco
# Processing Record 8 of Set 15 | burnie
# Processing Record 9 of Set 15 | gornopravdinsk
# Processing Record 10 of Set 15 | bereda
# Processing Record 11 of Set 15 | boffa
# Processing Record 12 of Set 15 | cam ranh
# Processing Record 13 of Set 15 | chaman
# Processing Record 14 of Set 15 | atar
# Processing Record 15 of Set 15 | palu
# Processing Record 16 of Set 15 | skagastrond
# City not found. Skipping...
# Processing Record 17 of Set 15 | bongandanga
# Processing Record 18 of Set 15 | dawson creek
# Processing Record 19 of Set 15 | grand-lahou
# Processing Record 20 of Set 15 | san rafael
# Processing Record 21 of Set 15 | olot
# Processing Record 22 of Set 15 | xingyi
# Processing Record 23 of Set 15 | luderitz
# Processing Record 24 of Set 15 | paredon
# Processing Record 25 of Set 15 | tolosa
# Processing Record 26 of Set 15 | yumen
# Processing Record 27 of Set 15 | denizli
# Processing Record 28 of Set 15 | harper
# Processing Record 29 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 30 of Set 15 | tonantins
# Processing Record 31 of Set 15 | george town
# Processing Record 32 of Set 15 | lae
# Processing Record 33 of Set 15 | maragogi
# Processing Record 34 of Set 15 | tuam
# Processing Record 35 of Set 15 | olafsvik
# Processing Record 36 of Set 15 | amapa
# Processing Record 37 of Set 15 | isangel
# Processing Record 38 of Set 15 | kargasok
# Processing Record 39 of Set 15 | anchorage
# Processing Record 40 of Set 15 | salalah
# Processing Record 41 of Set 15 | malatya
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Katiola   8.1333   -5.1000     74.01        85         100
# 1        Hamilton  39.1834  -84.5333     55.15        93          90
# 2       Busselton -33.6500  115.3333     53.58        83          95
# 3    Punta Arenas -53.1500  -70.9167     53.71        43           0
# 4         Ushuaia -54.8000  -68.3000     51.46        46           0
# 5  Saint-Philippe -21.3585   55.7679     69.39        81          74
# 6          Atuona  -9.8000 -139.0333     77.92        67           5
# 7   Mar Del Plata -38.0023  -57.5575     59.09        83          75
# 8       Namatanai  -3.6667  152.4333     84.58        70          94
# 9        Rosarito  32.3333 -117.0333     76.93        73          47
#
#    Wind Speed       Description
# 0        2.86   overcast clouds
# 1        1.01              mist
# 2        4.29   overcast clouds
# 3       14.97         clear sky
# 4       18.41         clear sky
# 5        2.33     broken clouds
# 6       11.95         clear sky
# 7        1.99     broken clouds
# 8        8.21        light rain
# 9        9.22  scattered clouds

# %%
#create the output file (csv)
output_data_file = "WeatherPy_Database.cvs"
#export the city_data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
